# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## Import Section

# %%
import string
import random

# %% [markdown]
# ## Defining the ideal condition to exist in universe for an organism(The gene we want as the output)
# ## "helloworld" for this research

# %%
total_possible_genes = string.ascii_lowercase
ideal_genes_to_survive = "helloworld"

# %% [markdown]
# ## Creating Organisms

# %%
class Organism:
    def __init__(self,gene_length=10,generation=0):
        self.gene_length = gene_length
        self.genes = random.sample(total_possible_genes, gene_length)
        self.mutated_gene_length = random.randint(0,5)
        self.generation = generation
        self.fitness_score = [abs(ord(i)-ord(j)) for i,j in zip(ideal_gene_to_survive, self.genes)]
        
    def mate(self,other):
        if (self.gene_length != other.gene_length) or (self.generation != other.generation):
            return "mating impossible"
        else:
            inherited_gene_length = self.gene_length - self.mutated_gene_length
            inherited_genes = random.sample(self.genes+other.genes,inherited_gene_length)
            possible_mutated_genes =  set(total_possible_genes) - (set(self.genes)|set(other.genes))
            mutated_genes = random.sample(list(possible_mutated_genes),self.mutated_gene_length)
            child = Organism(gene_length=self.gene_length,generation=(self.generation+1))
            child.genes = inherited_genes + mutated_genes
            random.shuffle(child.genes)
            return child
            
    def get_details(self):
        return {'generation' : self.generation, 'genes' : self.genes, 'fitness_score' : sum(self.fitness_score)}
    
    def __str__(self):
        return "".join(self.genes)

# %% [markdown]
# # Testing organisms and their mating

# %%
test_organism = Organism()
another_test_organism = Organism()
print(test_organism.get_details())
print(another_test_organism.get_details())
child_organism = test_organism.mate(another_test_organism)
print(child_organism.get_details())
# Out:
# {'generation': 0, 'genes': ['r', 'b', 'p', 'x', 'v', 'z', 'h', 'o', 'c', 'g'], 'fitness_score': 61}
# {'generation': 0, 'genes': ['w', 'v', 'p', 'z', 'n', 'f', 'm', 'k', 'y', 'r'], 'fitness_score': 104}
# {'generation': 1, 'genes': ['p', 'c', 'y', 'g', 'x', 'w', 'f', 'r', 'h', 'o'], 'fitness_score': 55}

# %% [markdown]
# ## Organism conditions are nearly done, Let's procced to create world where organisms can evolve

# %%
class World:
    def __init__(self,population=50,fixed=True):
        self.fixed = fixed
        self.iteration = 0
        self.mated = 0
        self.failed_mate = 0
        self.population = population
        self.organisms = []
        for _ in range(population):
            self.organisms.append(Organism())
        self.organisms = sorted(self.organisms, key=lambda org: sum(org.fitness_score))
    def iterate(self):
        self.iteration += 1
        for i in range(len(self.organisms)-1):
            child = self.organisms[i].mate(self.organisms[i+1])
            if child != "mating impossible":
                self.organisms.append(child)
                self.mated += 1
            else:
                self.failed_mate += 1
        
        if self.fixed == True:
            self.organisms = sorted(self.organisms, key=lambda org: sum(org.fitness_score))[:self.population]
        else:
            self.organisms = sorted(self.organisms, key=lambda org: sum(org.fitness_score))
            
    def view_world(self):
        print("Iteration:", self.iteration)
        print("Successful Mating: ", self.mated)
        print("Mating Tried, But Failed: ", self.failed_mate)
        for org in self.organisms:
            print(org.get_details())

# %%
test_world = World()
test_world.view_world()
# Out:
# Iteration: 0
# Successful Mating:  0
# Mating Tried, But Failed:  0
# {'generation': 0, 'genes': ['h', 'n', 'k', 'f', 'g', 'm', 't', 'r', 'l', 'b'], 'fitness_score': 41}
# {'generation': 0, 'genes': ['o', 'a', 'f', 'p', 'r', 's', 'm', 'c', 'k', 'g'], 'fitness_score': 49}
# {'generation': 0, 'genes': ['i', 'h', 'a', 'g', 'l', 't', 'r', 'p', 'j', 'w'], 'fitness_score': 52}
# {'generation': 0, 'genes': ['t', 'm', 'h', 'x', 'l', 'z', 'q', 'u', 'p', 'b'], 'fitness_score': 53}
# {'generation': 0, 'genes': ['o', 'c', 'x', 'k', 'p', 'i', 'q', 'y', 'e', 'f'], 'fitness_score': 55}
# {'generation': 0, 'genes': ['f', 'l', 't', 'c', 'u', 'o', 'w', 'v', 'n', 'e'], 'fitness_score': 55}
# {'generation': 0, 'genes': ['l', 'i', 'h', 'f', 'r', 'c', 's', 'j', 'n', 'a'], 'fitness_score': 58}
# {'generation': 0, 'genes': ['o', 'u', 'y', 'l', 'n', 'z', 'r', 'q', 'd', 'k'], 'fitness_score': 59}
# {'generation': 0, 'genes': ['e', 'i', 'k', 'w', 'q', 's', 'f', 'b', 'o', 'l'], 'fitness_score': 61}
# {'generation': 0, 'genes': ['c', 'j', 's', 'y', 'n', 'v', 'h', 'o', 'g', 'r'], 'fitness_score': 61}
# {'generation': 0, 'genes': ['d', 'k', 'q', 'h', 'g', 'l', 'w', 's', 'y', 'b'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['i', 'h', 'b', 'd', 'r', 'k', 'l', 's', 'p', 'u'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['i', 'e', 'v', 'k', 'y', 'z', 'w', 'r', 'u', 'x'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['b', 's', 'j', 'm', 'n', 'p', 'q', 'w', 'v', 't'], 'fitness_score': 64}
# {'generation': 0, 'genes': ['d', 'v', 'g', 'n', 's', 'o', 't', 'i', 'x', 'f'], 'fitness_score': 68}
# {'generation': 0, 'genes': ['e', 'x', 'o', 'm', 'd', 'h', 'n', 'u', 't', 'i'], 'fitness_score': 69}
# {'generation': 0, 'genes': ['i', 'v', 'h', 'e', 'k', 'd', 'x', 'u', 'q', 'c'], 'fitness_score': 70}
# {'generation': 0, 'genes': ['o', 'd', 'w', 'g', 'f', 'p', 'r', 'k', 'y', 'l'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['o', 'u', 's', 'x', 'p', 'z', 'q', 'a', 'l', 'j'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['k', 'i', 's', 'a', 'l', 'g', 'h', 'u', 'e', 'o'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['c', 'd', 'o', 'u', 'v', 'i', 'f', 's', 'h', 'w'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['f', 'y', 'h', 't', 'x', 'w', 'a', 'm', 'o', 'k'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['z', 'e', 'y', 'v', 's', 't', 'n', 'a', 'm', 'i'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['r', 'g', 'c', 'p', 'j', 'e', 'n', 'h', 'q', 'l'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['w', 'f', 'm', 'd', 'i', 'l', 'n', 'v', 'o', 'z'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['v', 'a', 't', 'w', 'y', 'e', 'q', 'm', 'i', 'd'], 'fitness_score': 75}
# {'generation': 0, 'genes': ['c', 'w', 'x', 'g', 'r', 'u', 'm', 'e', 'a', 'i'], 'fitness_score': 76}
# {'generation': 0, 'genes': ['w', 'i', 'm', 'v', 'h', 't', 'j', 'a', 's', 'l'], 'fitness_score': 77}
# {'generation': 0, 'genes': ['i', 'h', 'v', 'u', 's', 'p', 'n', 'd', 'x', 't'], 'fitness_score': 77}
# {'generation': 0, 'genes': ['p', 's', 'f', 'z', 'h', 'y', 'w', 'e', 'r', 'd'], 'fitness_score': 78}
# {'generation': 0, 'genes': ['i', 'u', 'h', 'n', 'x', 'j', 'w', 'r', 'o', 'z'], 'fitness_score': 78}
# {'generation': 0, 'genes': ['s', 'm', 'b', 'p', 'r', 't', 'z', 'g', 'y', 'i'], 'fitness_score': 79}
# {'generation': 0, 'genes': ['g', 'x', 'f', 'w', 'j', 'n', 'b', 'r', 'a', 'h'], 'fitness_score': 79}
# {'generation': 0, 'genes': ['v', 'o', 't', 'a', 'w', 's', 'h', 'g', 'n', 'i'], 'fitness_score': 80}
# {'generation': 0, 'genes': ['c', 'w', 'n', 'f', 'r', 's', 'd', 'v', 'u', 'x'], 'fitness_score': 82}
# {'generation': 0, 'genes': ['d', 'o', 'f', 'g', 'q', 'r', 't', 'e', 'x', 'y'], 'fitness_score': 83}
# {'generation': 0, 'genes': ['v', 'r', 't', 'k', 'c', 'q', 'z', 'j', 'g', 'i'], 'fitness_score': 83}
# {'generation': 0, 'genes': ['o', 'd', 'v', 'f', 'p', 'e', 'h', 'j', 'r', 'x'], 'fitness_score': 84}
# {'generation': 0, 'genes': ['m', 'l', 'z', 'i', 'b', 'g', 'x', 'q', 'c', 'p'], 'fitness_score': 89}
# {'generation': 0, 'genes': ['c', 'h', 'q', 'v', 'x', 'm', 'k', 'g', 'z', 'w'], 'fitness_score': 90}
# {'generation': 0, 'genes': ['k', 'p', 'l', 'd', 'b', 'i', 'e', 'q', 'z', 't'], 'fitness_score': 90}
# {'generation': 0, 'genes': ['m', 'z', 'k', 'p', 'd', 'n', 'l', 'c', 'r', 's'], 'fitness_score': 90}
# {'generation': 0, 'genes': ['w', 'p', 'r', 'x', 'u', 'j', 'm', 's', 'z', 'o'], 'fitness_score': 91}
# {'generation': 0, 'genes': ['x', 'v', 'w', 'o', 'z', 't', 'g', 'f', 'j', 'l'], 'fitness_score': 91}
# {'generation': 0, 'genes': ['e', 'j', 'h', 'z', 't', 'c', 'r', 'b', 'i', 'w'], 'fitness_score': 92}
# {'generation': 0, 'genes': ['t', 'y', 'r', 'e', 'n', 'k', 'x', 'z', 'j', 'v'], 'fitness_score': 95}
# {'generation': 0, 'genes': ['n', 'k', 'w', 'e', 't', 'm', 'v', 'i', 'z', 'y'], 'fitness_score': 96}
# {'generation': 0, 'genes': ['r', 'j', 'a', 'k', 'd', 'c', 'u', 't', 'b', 'x'], 'fitness_score': 96}
# {'generation': 0, 'genes': ['p', 'w', 'd', 'e', 'v', 'f', 'x', 't', 's', 'z'], 'fitness_score': 105}
# {'generation': 0, 'genes': ['z', 't', 'k', 'u', 'r', 'n', 'a', 'c', 'v', 'w'], 'fitness_score': 113}

# %%
test_world.iterate()
test_world.view_world()
# Out:
# Iteration: 1
# Successful Mating:  49
# Mating Tried, But Failed:  0
# {'generation': 0, 'genes': ['h', 'n', 'k', 'f', 'g', 'm', 't', 'r', 'l', 'b'], 'fitness_score': 41}
# {'generation': 1, 'genes': ['b', 'r', 'w', 'h', 'l', 'q', 'e', 'f', 'y', 'g'], 'fitness_score': 42}
# {'generation': 1, 'genes': ['p', 'j', 't', 'm', 'u', 'f', 'h', 'q', 'o', 'k'], 'fitness_score': 47}
# {'generation': 0, 'genes': ['o', 'a', 'f', 'p', 'r', 's', 'm', 'c', 'k', 'g'], 'fitness_score': 49}
# {'generation': 1, 'genes': ['w', 'j', 'k', 's', 'd', 'o', 'b', 'y', 'v', 'n'], 'fitness_score': 51}
# {'generation': 1, 'genes': ['z', 'u', 'd', 'u', 'k', 'v', 'f', 'w', 'x', 'r'], 'fitness_score': 51}
# {'generation': 0, 'genes': ['i', 'h', 'a', 'g', 'l', 't', 'r', 'p', 'j', 'w'], 'fitness_score': 52}
# {'generation': 0, 'genes': ['t', 'm', 'h', 'x', 'l', 'z', 'q', 'u', 'p', 'b'], 'fitness_score': 53}
# {'generation': 1, 'genes': ['h', 'u', 'i', 'l', 'g', 'm', 'k', 'k', 'v', 's'], 'fitness_score': 54}
# {'generation': 0, 'genes': ['o', 'c', 'x', 'k', 'p', 'i', 'q', 'y', 'e', 'f'], 'fitness_score': 55}
# {'generation': 0, 'genes': ['f', 'l', 't', 'c', 'u', 'o', 'w', 'v', 'n', 'e'], 'fitness_score': 55}
# {'generation': 1, 'genes': ['n', 'm', 'v', 'd', 'c', 'h', 'r', 'l', 'f', 'e'], 'fitness_score': 57}
# {'generation': 0, 'genes': ['l', 'i', 'h', 'f', 'r', 'c', 's', 'j', 'n', 'a'], 'fitness_score': 58}
# {'generation': 1, 'genes': ['j', 'f', 'a', 'w', 'z', 'g', 'x', 'p', 's', 'm'], 'fitness_score': 58}
# {'generation': 0, 'genes': ['o', 'u', 'y', 'l', 'n', 'z', 'r', 'q', 'd', 'k'], 'fitness_score': 59}
# {'generation': 1, 'genes': ['u', 'i', 'e', 's', 'j', 'n', 'b', 'y', 'w', 't'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['e', 'i', 'k', 'w', 'q', 's', 'f', 'b', 'o', 'l'], 'fitness_score': 61}
# {'generation': 0, 'genes': ['c', 'j', 's', 'y', 'n', 'v', 'h', 'o', 'g', 'r'], 'fitness_score': 61}
# {'generation': 0, 'genes': ['d', 'k', 'q', 'h', 'g', 'l', 'w', 's', 'y', 'b'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['i', 'h', 'b', 'd', 'r', 'k', 'l', 's', 'p', 'u'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['i', 'e', 'v', 'k', 'y', 'z', 'w', 'r', 'u', 'x'], 'fitness_score': 62}
# {'generation': 1, 'genes': ['q', 'n', 'f', 'j', 'y', 'k', 'z', 'p', 'a', 'v'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['b', 's', 'j', 'm', 'n', 'p', 'q', 'w', 'v', 't'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['o', 'z', 'd', 'u', 't', 'm', 'p', 'j', 'c', 'n'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['s', 'o', 'p', 'd', 's', 'm', 'x', 'u', 'v', 'w'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['p', 'h', 'j', 'n', 'v', 'x', 'm', 'z', 'r', 'e'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['g', 'e', 'w', 's', 'r', 'm', 'y', 'v', 'v', 'e'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['y', 'u', 'g', 'p', 'l', 's', 'a', 'x', 't', 'z'], 'fitness_score': 65}
# {'generation': 1, 'genes': ['o', 'r', 'y', 'e', 'q', 'd', 'f', 'q', 'z', 'k'], 'fitness_score': 66}
# {'generation': 0, 'genes': ['d', 'v', 'g', 'n', 's', 'o', 't', 'i', 'x', 'f'], 'fitness_score': 68}
# {'generation': 0, 'genes': ['e', 'x', 'o', 'm', 'd', 'h', 'n', 'u', 't', 'i'], 'fitness_score': 69}
# {'generation': 1, 'genes': ['x', 'g', 'y', 'f', 'l', 'o', 'c', 'h', 'u', 'e'], 'fitness_score': 69}
# {'generation': 1, 'genes': ['j', 'g', 'v', 'm', 'p', 'j', 'c', 'v', 'r', 'y'], 'fitness_score': 69}
# {'generation': 0, 'genes': ['i', 'v', 'h', 'e', 'k', 'd', 'x', 'u', 'q', 'c'], 'fitness_score': 70}
# {'generation': 1, 'genes': ['v', 'w', 'n', 'm', 'l', 'c', 't', 'u', 'y', 'f'], 'fitness_score': 70}
# {'generation': 0, 'genes': ['o', 'd', 'w', 'g', 'f', 'p', 'r', 'k', 'y', 'l'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['o', 'u', 's', 'x', 'p', 'z', 'q', 'a', 'l', 'j'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['k', 'i', 's', 'a', 'l', 'g', 'h', 'u', 'e', 'o'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['c', 'd', 'o', 'u', 'v', 'i', 'f', 's', 'h', 'w'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['f', 'y', 'h', 't', 'x', 'w', 'a', 'm', 'o', 'k'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['z', 'e', 'y', 'v', 's', 't', 'n', 'a', 'm', 'i'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['r', 'g', 'c', 'p', 'j', 'e', 'n', 'h', 'q', 'l'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['w', 'f', 'm', 'd', 'i', 'l', 'n', 'v', 'o', 'z'], 'fitness_score': 72}
# {'generation': 1, 'genes': ['m', 'l', 'q', 'h', 'g', 't', 'j', 'i', 'a', 'v'], 'fitness_score': 73}
# {'generation': 1, 'genes': ['n', 't', 'p', 's', 's', 'd', 'r', 'y', 'h', 'q'], 'fitness_score': 74}
# {'generation': 0, 'genes': ['v', 'a', 't', 'w', 'y', 'e', 'q', 'm', 'i', 'd'], 'fitness_score': 75}
# {'generation': 1, 'genes': ['x', 'r', 'l', 'p', 'z', 'z', 'w', 'g', 'i', 'a'], 'fitness_score': 75}
# {'generation': 0, 'genes': ['c', 'w', 'x', 'g', 'r', 'u', 'm', 'e', 'a', 'i'], 'fitness_score': 76}
# {'generation': 0, 'genes': ['w', 'i', 'm', 'v', 'h', 't', 'j', 'a', 's', 'l'], 'fitness_score': 77}
# {'generation': 0, 'genes': ['i', 'h', 'v', 'u', 's', 'p', 'n', 'd', 'x', 't'], 'fitness_score': 77}

# %%
test_world.iterate()
test_world.view_world()
# Out:
# Iteration: 2
# Successful Mating:  74
# Mating Tried, But Failed:  24
# {'generation': 2, 'genes': ['i', 'q', 'c', 'p', 'g', 't', 's', 'r', 'y', 'h'], 'fitness_score': 37}
# {'generation': 0, 'genes': ['h', 'n', 'k', 'f', 'g', 'm', 't', 'r', 'l', 'b'], 'fitness_score': 41}
# {'generation': 1, 'genes': ['b', 'r', 'w', 'h', 'l', 'q', 'e', 'f', 'y', 'g'], 'fitness_score': 42}
# {'generation': 2, 'genes': ['k', 'y', 'u', 'u', 'w', 'd', 'z', 's', 'j', 'n'], 'fitness_score': 44}
# {'generation': 1, 'genes': ['h', 'a', 't', 'i', 'y', 'b', 'h', 'q', 'b', 's'], 'fitness_score': 45}
# {'generation': 1, 'genes': ['p', 'j', 't', 'm', 'u', 'f', 'h', 'q', 'o', 'k'], 'fitness_score': 47}
# {'generation': 0, 'genes': ['o', 'a', 'f', 'p', 'r', 's', 'm', 'c', 'k', 'g'], 'fitness_score': 49}
# {'generation': 1, 'genes': ['w', 'j', 'k', 's', 'd', 'o', 'b', 'y', 'v', 'n'], 'fitness_score': 51}
# {'generation': 1, 'genes': ['z', 'u', 'd', 'u', 'k', 'v', 'f', 'w', 'x', 'r'], 'fitness_score': 51}
# {'generation': 0, 'genes': ['i', 'h', 'a', 'g', 'l', 't', 'r', 'p', 'j', 'w'], 'fitness_score': 52}
# {'generation': 0, 'genes': ['t', 'm', 'h', 'x', 'l', 'z', 'q', 'u', 'p', 'b'], 'fitness_score': 53}
# {'generation': 1, 'genes': ['h', 'u', 'i', 'l', 'g', 'm', 'k', 'k', 'v', 's'], 'fitness_score': 54}
# {'generation': 0, 'genes': ['o', 'c', 'x', 'k', 'p', 'i', 'q', 'y', 'e', 'f'], 'fitness_score': 55}
# {'generation': 0, 'genes': ['f', 'l', 't', 'c', 'u', 'o', 'w', 'v', 'n', 'e'], 'fitness_score': 55}
# {'generation': 2, 'genes': ['p', 'c', 's', 'v', 'o', 'm', 'd', 'x', 's', 'j'], 'fitness_score': 56}
# {'generation': 2, 'genes': ['m', 'o', 'u', 'n', 'm', 'v', 'h', 'w', 'p', 'g'], 'fitness_score': 56}
# {'generation': 1, 'genes': ['n', 'm', 'v', 'd', 'c', 'h', 'r', 'l', 'f', 'e'], 'fitness_score': 57}
# {'generation': 0, 'genes': ['l', 'i', 'h', 'f', 'r', 'c', 's', 'j', 'n', 'a'], 'fitness_score': 58}
# {'generation': 1, 'genes': ['j', 'f', 'a', 'w', 'z', 'g', 'x', 'p', 's', 'm'], 'fitness_score': 58}
# {'generation': 2, 'genes': ['b', 'r', 'u', 'e', 'z', 'o', 't', 'p', 'f', 'g'], 'fitness_score': 58}
# {'generation': 0, 'genes': ['o', 'u', 'y', 'l', 'n', 'z', 'r', 'q', 'd', 'k'], 'fitness_score': 59}
# {'generation': 1, 'genes': ['u', 'i', 'e', 's', 'j', 'n', 'b', 'y', 'w', 't'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['e', 'i', 'k', 'w', 'q', 's', 'f', 'b', 'o', 'l'], 'fitness_score': 61}
# {'generation': 0, 'genes': ['c', 'j', 's', 'y', 'n', 'v', 'h', 'o', 'g', 'r'], 'fitness_score': 61}
# {'generation': 0, 'genes': ['d', 'k', 'q', 'h', 'g', 'l', 'w', 's', 'y', 'b'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['i', 'h', 'b', 'd', 'r', 'k', 'l', 's', 'p', 'u'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['i', 'e', 'v', 'k', 'y', 'z', 'w', 'r', 'u', 'x'], 'fitness_score': 62}
# {'generation': 1, 'genes': ['q', 'n', 'f', 'j', 'y', 'k', 'z', 'p', 'a', 'v'], 'fitness_score': 62}
# {'generation': 1, 'genes': ['r', 'v', 'o', 'z', 'd', 'u', 'o', 'i', 'f', 't'], 'fitness_score': 63}
# {'generation': 0, 'genes': ['b', 's', 'j', 'm', 'n', 'p', 'q', 'w', 'v', 't'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['o', 'z', 'd', 'u', 't', 'm', 'p', 'j', 'c', 'n'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['s', 'o', 'p', 'd', 's', 'm', 'x', 'u', 'v', 'w'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['p', 'h', 'j', 'n', 'v', 'x', 'm', 'z', 'r', 'e'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['g', 'e', 'w', 's', 'r', 'm', 'y', 'v', 'v', 'e'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['y', 'u', 'g', 'p', 'l', 's', 'a', 'x', 't', 'z'], 'fitness_score': 65}
# {'generation': 1, 'genes': ['o', 'r', 'y', 'e', 'q', 'd', 'f', 'q', 'z', 'k'], 'fitness_score': 66}
# {'generation': 2, 'genes': ['w', 'q', 'e', 'k', 'r', 'p', 'd', 'y', 't', 'q'], 'fitness_score': 67}
# {'generation': 1, 'genes': ['s', 'o', 'p', 'i', 'w', 'g', 'v', 'n', 'q', 'f'], 'fitness_score': 67}
# {'generation': 0, 'genes': ['d', 'v', 'g', 'n', 's', 'o', 't', 'i', 'x', 'f'], 'fitness_score': 68}
# {'generation': 2, 'genes': ['c', 'p', 'r', 'f', 'o', 'm', 'z', 'v', 'd', 'b'], 'fitness_score': 68}
# {'generation': 0, 'genes': ['e', 'x', 'o', 'm', 'd', 'h', 'n', 'u', 't', 'i'], 'fitness_score': 69}
# {'generation': 1, 'genes': ['x', 'g', 'y', 'f', 'l', 'o', 'c', 'h', 'u', 'e'], 'fitness_score': 69}
# {'generation': 1, 'genes': ['j', 'g', 'v', 'm', 'p', 'j', 'c', 'v', 'r', 'y'], 'fitness_score': 69}
# {'generation': 1, 'genes': ['n', 'i', 'h', 'b', 'l', 'i', 'r', 'w', 'k', 'x'], 'fitness_score': 69}
# {'generation': 2, 'genes': ['h', 'u', 'l', 's', 'z', 'n', 'c', 'g', 'c', 'w'], 'fitness_score': 69}
# {'generation': 0, 'genes': ['i', 'v', 'h', 'e', 'k', 'd', 'x', 'u', 'q', 'c'], 'fitness_score': 70}
# {'generation': 1, 'genes': ['v', 'w', 'n', 'm', 'l', 'c', 't', 'u', 'y', 'f'], 'fitness_score': 70}
# {'generation': 0, 'genes': ['o', 'd', 'w', 'g', 'f', 'p', 'r', 'k', 'y', 'l'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['o', 'u', 's', 'x', 'p', 'z', 'q', 'a', 'l', 'j'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['k', 'i', 's', 'a', 'l', 'g', 'h', 'u', 'e', 'o'], 'fitness_score': 72}

# %%
test_world.iterate()
test_world.view_world()
# Out:
# Iteration: 3
# Successful Mating:  93
# Mating Tried, But Failed:  54
# {'generation': 2, 'genes': ['i', 'q', 'c', 'p', 'g', 't', 's', 'r', 'y', 'h'], 'fitness_score': 37}
# {'generation': 0, 'genes': ['h', 'n', 'k', 'f', 'g', 'm', 't', 'r', 'l', 'b'], 'fitness_score': 41}
# {'generation': 2, 'genes': ['r', 'x', 'g', 'y', 'n', 's', 'w', 'a', 'c', 'p'], 'fitness_score': 41}
# {'generation': 1, 'genes': ['b', 'r', 'w', 'h', 'l', 'q', 'e', 'f', 'y', 'g'], 'fitness_score': 42}
# {'generation': 2, 'genes': ['k', 'y', 'u', 'u', 'w', 'd', 'z', 's', 'j', 'n'], 'fitness_score': 44}
# {'generation': 1, 'genes': ['h', 'a', 't', 'i', 'y', 'b', 'h', 'q', 'b', 's'], 'fitness_score': 45}
# {'generation': 1, 'genes': ['p', 'j', 't', 'm', 'u', 'f', 'h', 'q', 'o', 'k'], 'fitness_score': 47}
# {'generation': 0, 'genes': ['o', 'a', 'f', 'p', 'r', 's', 'm', 'c', 'k', 'g'], 'fitness_score': 49}
# {'generation': 1, 'genes': ['h', 'z', 'k', 'p', 'd', 'b', 'g', 's', 'm', 'l'], 'fitness_score': 49}
# {'generation': 1, 'genes': ['w', 'j', 'k', 's', 'd', 'o', 'b', 'y', 'v', 'n'], 'fitness_score': 51}
# {'generation': 1, 'genes': ['z', 'u', 'd', 'u', 'k', 'v', 'f', 'w', 'x', 'r'], 'fitness_score': 51}
# {'generation': 0, 'genes': ['i', 'h', 'a', 'g', 'l', 't', 'r', 'p', 'j', 'w'], 'fitness_score': 52}
# {'generation': 0, 'genes': ['t', 'm', 'h', 'x', 'l', 'z', 'q', 'u', 'p', 'b'], 'fitness_score': 53}
# {'generation': 1, 'genes': ['h', 'u', 'i', 'l', 'g', 'm', 'k', 'k', 'v', 's'], 'fitness_score': 54}
# {'generation': 0, 'genes': ['o', 'c', 'x', 'k', 'p', 'i', 'q', 'y', 'e', 'f'], 'fitness_score': 55}
# {'generation': 0, 'genes': ['f', 'l', 't', 'c', 'u', 'o', 'w', 'v', 'n', 'e'], 'fitness_score': 55}
# {'generation': 2, 'genes': ['p', 'c', 's', 'v', 'o', 'm', 'd', 'x', 's', 'j'], 'fitness_score': 56}
# {'generation': 2, 'genes': ['m', 'o', 'u', 'n', 'm', 'v', 'h', 'w', 'p', 'g'], 'fitness_score': 56}
# {'generation': 1, 'genes': ['n', 'm', 'v', 'd', 'c', 'h', 'r', 'l', 'f', 'e'], 'fitness_score': 57}
# {'generation': 0, 'genes': ['l', 'i', 'h', 'f', 'r', 'c', 's', 'j', 'n', 'a'], 'fitness_score': 58}
# {'generation': 1, 'genes': ['j', 'f', 'a', 'w', 'z', 'g', 'x', 'p', 's', 'm'], 'fitness_score': 58}
# {'generation': 2, 'genes': ['b', 'r', 'u', 'e', 'z', 'o', 't', 'p', 'f', 'g'], 'fitness_score': 58}
# {'generation': 0, 'genes': ['o', 'u', 'y', 'l', 'n', 'z', 'r', 'q', 'd', 'k'], 'fitness_score': 59}
# {'generation': 1, 'genes': ['h', 'j', 'q', 'h', 'k', 'i', 'o', 's', 'd', 'y'], 'fitness_score': 59}
# {'generation': 1, 'genes': ['u', 'i', 'e', 's', 'j', 'n', 'b', 'y', 'w', 't'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['e', 'i', 'k', 'w', 'q', 's', 'f', 'b', 'o', 'l'], 'fitness_score': 61}
# {'generation': 0, 'genes': ['c', 'j', 's', 'y', 'n', 'v', 'h', 'o', 'g', 'r'], 'fitness_score': 61}
# {'generation': 0, 'genes': ['d', 'k', 'q', 'h', 'g', 'l', 'w', 's', 'y', 'b'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['i', 'h', 'b', 'd', 'r', 'k', 'l', 's', 'p', 'u'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['i', 'e', 'v', 'k', 'y', 'z', 'w', 'r', 'u', 'x'], 'fitness_score': 62}
# {'generation': 1, 'genes': ['q', 'n', 'f', 'j', 'y', 'k', 'z', 'p', 'a', 'v'], 'fitness_score': 62}
# {'generation': 2, 'genes': ['x', 't', 'w', 'm', 'c', 'u', 'd', 'z', 'p', 'd'], 'fitness_score': 62}
# {'generation': 2, 'genes': ['q', 'g', 'a', 'l', 'q', 'k', 'u', 'x', 'i', 'z'], 'fitness_score': 62}
# {'generation': 1, 'genes': ['r', 'v', 'o', 'z', 'd', 'u', 'o', 'i', 'f', 't'], 'fitness_score': 63}
# {'generation': 0, 'genes': ['b', 's', 'j', 'm', 'n', 'p', 'q', 'w', 'v', 't'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['o', 'z', 'd', 'u', 't', 'm', 'p', 'j', 'c', 'n'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['s', 'o', 'p', 'd', 's', 'm', 'x', 'u', 'v', 'w'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['p', 'h', 'j', 'n', 'v', 'x', 'm', 'z', 'r', 'e'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['g', 'e', 'w', 's', 'r', 'm', 'y', 'v', 'v', 'e'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['y', 'u', 'g', 'p', 'l', 's', 'a', 'x', 't', 'z'], 'fitness_score': 65}
# {'generation': 1, 'genes': ['o', 'r', 'y', 'e', 'q', 'd', 'f', 'q', 'z', 'k'], 'fitness_score': 66}
# {'generation': 2, 'genes': ['w', 'q', 'e', 'k', 'r', 'p', 'd', 'y', 't', 'q'], 'fitness_score': 67}
# {'generation': 1, 'genes': ['s', 'o', 'p', 'i', 'w', 'g', 'v', 'n', 'q', 'f'], 'fitness_score': 67}
# {'generation': 0, 'genes': ['d', 'v', 'g', 'n', 's', 'o', 't', 'i', 'x', 'f'], 'fitness_score': 68}
# {'generation': 2, 'genes': ['c', 'p', 'r', 'f', 'o', 'm', 'z', 'v', 'd', 'b'], 'fitness_score': 68}
# {'generation': 0, 'genes': ['e', 'x', 'o', 'm', 'd', 'h', 'n', 'u', 't', 'i'], 'fitness_score': 69}
# {'generation': 1, 'genes': ['x', 'g', 'y', 'f', 'l', 'o', 'c', 'h', 'u', 'e'], 'fitness_score': 69}
# {'generation': 1, 'genes': ['j', 'g', 'v', 'm', 'p', 'j', 'c', 'v', 'r', 'y'], 'fitness_score': 69}
# {'generation': 1, 'genes': ['n', 'i', 'h', 'b', 'l', 'i', 'r', 'w', 'k', 'x'], 'fitness_score': 69}
# {'generation': 2, 'genes': ['h', 'u', 'l', 's', 'z', 'n', 'c', 'g', 'c', 'w'], 'fitness_score': 69}

# %%
test_world.iterate()
test_world.view_world()
# Out:
# Iteration: 4
# Successful Mating:  112
# Mating Tried, But Failed:  84
# {'generation': 2, 'genes': ['i', 'q', 'c', 'p', 'g', 't', 's', 'r', 'y', 'h'], 'fitness_score': 37}
# {'generation': 0, 'genes': ['h', 'n', 'k', 'f', 'g', 'm', 't', 'r', 'l', 'b'], 'fitness_score': 41}
# {'generation': 2, 'genes': ['r', 'x', 'g', 'y', 'n', 's', 'w', 'a', 'c', 'p'], 'fitness_score': 41}
# {'generation': 1, 'genes': ['b', 'r', 'w', 'h', 'l', 'q', 'e', 'f', 'y', 'g'], 'fitness_score': 42}
# {'generation': 2, 'genes': ['w', 'e', 'z', 't', 'k', 'x', 'm', 'y', 'v', 'n'], 'fitness_score': 43}
# {'generation': 2, 'genes': ['k', 'y', 'u', 'u', 'w', 'd', 'z', 's', 'j', 'n'], 'fitness_score': 44}
# {'generation': 1, 'genes': ['h', 'a', 't', 'i', 'y', 'b', 'h', 'q', 'b', 's'], 'fitness_score': 45}
# {'generation': 1, 'genes': ['p', 'j', 't', 'm', 'u', 'f', 'h', 'q', 'o', 'k'], 'fitness_score': 47}
# {'generation': 0, 'genes': ['o', 'a', 'f', 'p', 'r', 's', 'm', 'c', 'k', 'g'], 'fitness_score': 49}
# {'generation': 1, 'genes': ['h', 'z', 'k', 'p', 'd', 'b', 'g', 's', 'm', 'l'], 'fitness_score': 49}
# {'generation': 1, 'genes': ['w', 'j', 'k', 's', 'd', 'o', 'b', 'y', 'v', 'n'], 'fitness_score': 51}
# {'generation': 1, 'genes': ['z', 'u', 'd', 'u', 'k', 'v', 'f', 'w', 'x', 'r'], 'fitness_score': 51}
# {'generation': 0, 'genes': ['i', 'h', 'a', 'g', 'l', 't', 'r', 'p', 'j', 'w'], 'fitness_score': 52}
# {'generation': 0, 'genes': ['t', 'm', 'h', 'x', 'l', 'z', 'q', 'u', 'p', 'b'], 'fitness_score': 53}
# {'generation': 1, 'genes': ['h', 'u', 'i', 'l', 'g', 'm', 'k', 'k', 'v', 's'], 'fitness_score': 54}
# {'generation': 0, 'genes': ['o', 'c', 'x', 'k', 'p', 'i', 'q', 'y', 'e', 'f'], 'fitness_score': 55}
# {'generation': 0, 'genes': ['f', 'l', 't', 'c', 'u', 'o', 'w', 'v', 'n', 'e'], 'fitness_score': 55}
# {'generation': 2, 'genes': ['p', 'c', 's', 'v', 'o', 'm', 'd', 'x', 's', 'j'], 'fitness_score': 56}
# {'generation': 2, 'genes': ['m', 'o', 'u', 'n', 'm', 'v', 'h', 'w', 'p', 'g'], 'fitness_score': 56}
# {'generation': 1, 'genes': ['n', 'm', 'v', 'd', 'c', 'h', 'r', 'l', 'f', 'e'], 'fitness_score': 57}
# {'generation': 0, 'genes': ['l', 'i', 'h', 'f', 'r', 'c', 's', 'j', 'n', 'a'], 'fitness_score': 58}
# {'generation': 1, 'genes': ['j', 'f', 'a', 'w', 'z', 'g', 'x', 'p', 's', 'm'], 'fitness_score': 58}
# {'generation': 2, 'genes': ['b', 'r', 'u', 'e', 'z', 'o', 't', 'p', 'f', 'g'], 'fitness_score': 58}
# {'generation': 0, 'genes': ['o', 'u', 'y', 'l', 'n', 'z', 'r', 'q', 'd', 'k'], 'fitness_score': 59}
# {'generation': 1, 'genes': ['h', 'j', 'q', 'h', 'k', 'i', 'o', 's', 'd', 'y'], 'fitness_score': 59}
# {'generation': 1, 'genes': ['u', 'i', 'e', 's', 'j', 'n', 'b', 'y', 'w', 't'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['e', 'i', 'k', 'w', 'q', 's', 'f', 'b', 'o', 'l'], 'fitness_score': 61}
# {'generation': 0, 'genes': ['c', 'j', 's', 'y', 'n', 'v', 'h', 'o', 'g', 'r'], 'fitness_score': 61}
# {'generation': 1, 'genes': ['a', 'k', 'd', 'e', 'l', 'x', 'v', 'b', 'u', 'z'], 'fitness_score': 61}
# {'generation': 0, 'genes': ['d', 'k', 'q', 'h', 'g', 'l', 'w', 's', 'y', 'b'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['i', 'h', 'b', 'd', 'r', 'k', 'l', 's', 'p', 'u'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['i', 'e', 'v', 'k', 'y', 'z', 'w', 'r', 'u', 'x'], 'fitness_score': 62}
# {'generation': 1, 'genes': ['q', 'n', 'f', 'j', 'y', 'k', 'z', 'p', 'a', 'v'], 'fitness_score': 62}
# {'generation': 2, 'genes': ['x', 't', 'w', 'm', 'c', 'u', 'd', 'z', 'p', 'd'], 'fitness_score': 62}
# {'generation': 2, 'genes': ['q', 'g', 'a', 'l', 'q', 'k', 'u', 'x', 'i', 'z'], 'fitness_score': 62}
# {'generation': 1, 'genes': ['r', 'v', 'o', 'z', 'd', 'u', 'o', 'i', 'f', 't'], 'fitness_score': 63}
# {'generation': 0, 'genes': ['b', 's', 'j', 'm', 'n', 'p', 'q', 'w', 'v', 't'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['o', 'z', 'd', 'u', 't', 'm', 'p', 'j', 'c', 'n'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['s', 'o', 'p', 'd', 's', 'm', 'x', 'u', 'v', 'w'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['p', 'h', 'j', 'n', 'v', 'x', 'm', 'z', 'r', 'e'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['g', 'e', 'w', 's', 'r', 'm', 'y', 'v', 'v', 'e'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['y', 'u', 'g', 'p', 'l', 's', 'a', 'x', 't', 'z'], 'fitness_score': 65}
# {'generation': 1, 'genes': ['o', 'r', 'y', 'e', 'q', 'd', 'f', 'q', 'z', 'k'], 'fitness_score': 66}
# {'generation': 2, 'genes': ['w', 'q', 'e', 'k', 'r', 'p', 'd', 'y', 't', 'q'], 'fitness_score': 67}
# {'generation': 1, 'genes': ['s', 'o', 'p', 'i', 'w', 'g', 'v', 'n', 'q', 'f'], 'fitness_score': 67}
# {'generation': 2, 'genes': ['y', 'j', 't', 'q', 's', 'o', 'k', 'b', 'b', 'h'], 'fitness_score': 67}
# {'generation': 0, 'genes': ['d', 'v', 'g', 'n', 's', 'o', 't', 'i', 'x', 'f'], 'fitness_score': 68}
# {'generation': 2, 'genes': ['c', 'p', 'r', 'f', 'o', 'm', 'z', 'v', 'd', 'b'], 'fitness_score': 68}
# {'generation': 3, 'genes': ['u', 'j', 'm', 'c', 'v', 'l', 't', 'g', 'k', 's'], 'fitness_score': 68}
# {'generation': 0, 'genes': ['e', 'x', 'o', 'm', 'd', 'h', 'n', 'u', 't', 'i'], 'fitness_score': 69}

# %% [markdown]
# ## Manual Analysis done, now automation

# %%
new_world = World()
new_world.view_world()
for i in range(100):
    new_world.iterate()
new_world.view_world()
# Out:
# Iteration: 0
# Successful Mating:  0
# Mating Tried, But Failed:  0
# {'generation': 0, 'genes': ['r', 'd', 'p', 'j', 'q', 'u', 'l', 'x', 'n', 'f'], 'fitness_score': 34}
# {'generation': 0, 'genes': ['i', 'd', 'h', 's', 'f', 'y', 'o', 'j', 't', 'b'], 'fitness_score': 42}
# {'generation': 0, 'genes': ['u', 'd', 'k', 'l', 's', 'z', 'r', 'x', 'b', 'a'], 'fitness_score': 44}
# {'generation': 0, 'genes': ['e', 'h', 'n', 'b', 'g', 'y', 'p', 'v', 'x', 'd'], 'fitness_score': 45}
# {'generation': 0, 'genes': ['d', 'l', 'i', 'c', 'u', 'm', 'k', 't', 'g', 'e'], 'fitness_score': 51}
# {'generation': 0, 'genes': ['c', 'i', 'h', 'b', 'd', 'w', 'n', 'q', 'p', 'u'], 'fitness_score': 57}
# {'generation': 0, 'genes': ['c', 'd', 'l', 'o', 'b', 'z', 'v', 's', 'q', 'x'], 'fitness_score': 58}
# {'generation': 0, 'genes': ['h', 'p', 'l', 'f', 'y', 'v', 'a', 'u', 'c', 'i'], 'fitness_score': 59}
# {'generation': 0, 'genes': ['n', 'q', 'j', 'i', 'p', 'k', 'o', 'g', 't', 'h'], 'fitness_score': 59}
# {'generation': 0, 'genes': ['a', 't', 'b', 'o', 'z', 'y', 'v', 'r', 'h', 'c'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['j', 'z', 't', 'p', 'k', 'v', 'l', 'd', 'n', 'c'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['g', 'r', 'l', 'b', 'f', 'w', 'h', 'n', 's', 'm'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['l', 'g', 'i', 'j', 'o', 'r', 'a', 'u', 'w', 'v'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['x', 'o', 'q', 'm', 'y', 'r', 'h', 'j', 'k', 'e'], 'fitness_score': 64}
# {'generation': 0, 'genes': ['i', 'g', 'w', 'e', 's', 'k', 'u', 'j', 'a', 'f'], 'fitness_score': 64}
# {'generation': 0, 'genes': ['e', 'f', 'c', 'w', 'z', 'k', 'x', 'i', 'l', 'd'], 'fitness_score': 65}
# {'generation': 0, 'genes': ['s', 'j', 'f', 'a', 'i', 'g', 'h', 'v', 'o', 'c'], 'fitness_score': 70}
# {'generation': 0, 'genes': ['g', 't', 'c', 'u', 'r', 'i', 'l', 'v', 'b', 'a'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['x', 'u', 'q', 'g', 's', 'p', 'w', 'h', 'k', 'd'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['f', 'q', 'w', 'o', 'x', 'm', 'c', 'y', 'k', 'i'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['t', 'k', 'u', 'x', 'n', 'r', 's', 'g', 'w', 'f'], 'fitness_score': 73}
# {'generation': 0, 'genes': ['v', 's', 'h', 'p', 'm', 'o', 'a', 'q', 'c', 'g'], 'fitness_score': 73}
# {'generation': 0, 'genes': ['t', 'j', 'u', 'v', 'd', 'y', 'b', 'l', 'o', 'f'], 'fitness_score': 73}
# {'generation': 0, 'genes': ['l', 'n', 'w', 'u', 'z', 'o', 'g', 'r', 't', 'i'], 'fitness_score': 73}
# {'generation': 0, 'genes': ['o', 'e', 'k', 'x', 'd', 'b', 't', 'p', 'g', 'm'], 'fitness_score': 73}
# {'generation': 0, 'genes': ['m', 'i', 'j', 'b', 's', 'n', 'y', 'w', 'h', 'x'], 'fitness_score': 73}
# {'generation': 0, 'genes': ['d', 'w', 'b', 'g', 'z', 'x', 'y', 'f', 'j', 'h'], 'fitness_score': 77}
# {'generation': 0, 'genes': ['c', 'l', 'v', 'z', 'h', 'p', 'b', 'r', 'j', 'q'], 'fitness_score': 78}
# {'generation': 0, 'genes': ['f', 'n', 'z', 't', 'y', 'b', 'k', 'u', 'r', 'c'], 'fitness_score': 78}
# {'generation': 0, 'genes': ['x', 'd', 'c', 'l', 'a', 'w', 'z', 'k', 's', 'r'], 'fitness_score': 79}
# {'generation': 0, 'genes': ['t', 'i', 'x', 'a', 'm', 'g', 'r', 'n', 'z', 'e'], 'fitness_score': 79}
# {'generation': 0, 'genes': ['g', 'x', 'j', 'u', 's', 'v', 'e', 'y', 'd', 'w'], 'fitness_score': 80}
# {'generation': 0, 'genes': ['d', 'w', 'a', 'g', 'n', 'c', 'l', 'y', 'r', 'j'], 'fitness_score': 81}
# {'generation': 0, 'genes': ['p', 'w', 'f', 'n', 'h', 'z', 's', 'r', 'y', 'x'], 'fitness_score': 81}
# {'generation': 0, 'genes': ['c', 'h', 'n', 'r', 'a', 'l', 'x', 'y', 'z', 'o'], 'fitness_score': 82}
# {'generation': 0, 'genes': ['g', 't', 'i', 'z', 'a', 'y', 'b', 'm', 's', 'n'], 'fitness_score': 84}
# {'generation': 0, 'genes': ['o', 'r', 'u', 'b', 't', 'i', 'x', 'z', 's', 'f'], 'fitness_score': 84}
# {'generation': 0, 'genes': ['p', 'u', 'c', 'b', 'r', 'f', 'k', 'm', 'v', 'g'], 'fitness_score': 85}
# {'generation': 0, 'genes': ['q', 'e', 'z', 'l', 'j', 'y', 'a', 'g', 'w', 'x'], 'fitness_score': 86}
# {'generation': 0, 'genes': ['p', 'n', 'w', 'r', 'b', 'q', 'h', 'd', 'j', 'o'], 'fitness_score': 87}
# {'generation': 0, 'genes': ['o', 'n', 'e', 'k', 'f', 'g', 'q', 's', 'y', 'z'], 'fitness_score': 87}
# {'generation': 0, 'genes': ['z', 'o', 't', 'r', 'l', 'h', 'p', 'c', 'v', 'b'], 'fitness_score': 88}
# {'generation': 0, 'genes': ['g', 'y', 'p', 'e', 'w', 'c', 'k', 'h', 'x', 'f'], 'fitness_score': 88}
# {'generation': 0, 'genes': ['h', 'g', 'c', 'd', 'w', 'b', 'a', 'i', 'q', 's'], 'fitness_score': 91}
# {'generation': 0, 'genes': ['b', 'u', 'm', 'd', 'x', 'g', 's', 'c', 'a', 'i'], 'fitness_score': 91}
# {'generation': 0, 'genes': ['x', 't', 'a', 'm', 'n', 'o', 'f', 'd', 'y', 'h'], 'fitness_score': 92}
# {'generation': 0, 'genes': ['t', 'q', 'w', 'a', 'v', 'c', 'p', 'm', 'z', 'f'], 'fitness_score': 95}
# {'generation': 0, 'genes': ['y', 'h', 'a', 'g', 'p', 'c', 'f', 'i', 'j', 'w'], 'fitness_score': 96}
# {'generation': 0, 'genes': ['v', 'u', 'w', 'a', 'e', 's', 'b', 'c', 'm', 'g'], 'fitness_score': 98}
# {'generation': 0, 'genes': ['f', 'u', 's', 't', 'j', 'b', 'o', 'e', 'a', 'x'], 'fitness_score': 103}
# Iteration: 100
# Successful Mating:  1097
# Mating Tried, But Failed:  3803
# {'generation': 3, 'genes': ['v', 'n', 'm', 'o', 'l', 'h', 'b', 'g', 'f', 'y'], 'fitness_score': 27}
# {'generation': 4, 'genes': ['v', 'l', 'y', 'k', 'c', 's', 'h', 'i', 'n', 'o'], 'fitness_score': 30}
# {'generation': 0, 'genes': ['r', 'd', 'p', 'j', 'q', 'u', 'l', 'x', 'n', 'f'], 'fitness_score': 34}
# {'generation': 1, 'genes': ['s', 'b', 'v', 'a', 'm', 'u', 'f', 'b', 'e', 'c'], 'fitness_score': 36}
# {'generation': 3, 'genes': ['u', 'm', 'j', 'c', 'b', 'f', 'y', 'x', 't', 'a'], 'fitness_score': 36}
# {'generation': 4, 'genes': ['h', 's', 'n', 'k', 'o', 'e', 'y', 'm', 'c', 'u'], 'fitness_score': 36}
# {'generation': 1, 'genes': ['a', 'w', 'v', 'm', 'z', 'i', 'e', 't', 'g', 'q'], 'fitness_score': 37}
# {'generation': 4, 'genes': ['n', 'o', 'q', 'd', 'o', 'h', 'w', 'd', 'w', 'r'], 'fitness_score': 38}
# {'generation': 5, 'genes': ['w', 'm', 'a', 'o', 'c', 'a', 'n', 'd', 'e', 'x'], 'fitness_score': 38}
# {'generation': 3, 'genes': ['o', 'k', 't', 'i', 't', 'u', 'j', 'a', 'f', 'w'], 'fitness_score': 39}
# {'generation': 4, 'genes': ['j', 'n', 'd', 'a', 'd', 'q', 'g', 'e', 'x', 'o'], 'fitness_score': 39}
# {'generation': 3, 'genes': ['v', 'r', 'm', 'y', 'd', 'h', 't', 'n', 'e', 'y'], 'fitness_score': 40}
# {'generation': 3, 'genes': ['h', 'u', 'y', 't', 'o', 'i', 's', 'f', 'v', 'e'], 'fitness_score': 40}
# {'generation': 2, 'genes': ['u', 'j', 'w', 'x', 'v', 'x', 's', 'd', 'h', 'r'], 'fitness_score': 41}
# {'generation': 3, 'genes': ['a', 'z', 'f', 'z', 'g', 'y', 'n', 'h', 'n', 'o'], 'fitness_score': 41}
# {'generation': 0, 'genes': ['i', 'd', 'h', 's', 'f', 'y', 'o', 'j', 't', 'b'], 'fitness_score': 42}
# {'generation': 3, 'genes': ['k', 'c', 's', 'y', 'i', 'w', 'f', 'a', 'h', 'r'], 'fitness_score': 42}
# {'generation': 5, 'genes': ['f', 'n', 'v', 's', 'o', 'w', 'j', 'z', 'd', 'p'], 'fitness_score': 42}
# {'generation': 2, 'genes': ['d', 'b', 'y', 't', 'l', 'f', 'z', 'v', 's', 'x'], 'fitness_score': 43}
# {'generation': 4, 'genes': ['u', 'e', 'o', 'h', 'c', 'w', 'g', 'n', 'm', 's'], 'fitness_score': 43}
# {'generation': 4, 'genes': ['a', 'x', 'q', 'c', 'e', 'w', 'n', 'j', 'd', 'h'], 'fitness_score': 43}
# {'generation': 0, 'genes': ['u', 'd', 'k', 'l', 's', 'z', 'r', 'x', 'b', 'a'], 'fitness_score': 44}
# {'generation': 2, 'genes': ['z', 'd', 'q', 'w', 'v', 'c', 'e', 'k', 'j', 'l'], 'fitness_score': 44}
# {'generation': 0, 'genes': ['e', 'h', 'n', 'b', 'g', 'y', 'p', 'v', 'x', 'd'], 'fitness_score': 45}
# {'generation': 1, 'genes': ['l', 'u', 'k', 'x', 'k', 'm', 'f', 'o', 'i', 'q'], 'fitness_score': 45}
# {'generation': 1, 'genes': ['b', 'n', 't', 'p', 'r', 'j', 'a', 'x', 'z', 'g'], 'fitness_score': 45}
# {'generation': 3, 'genes': ['p', 'c', 'v', 'q', 'o', 'u', 'm', 's', 'x', 'd'], 'fitness_score': 45}
# {'generation': 3, 'genes': ['e', 'r', 'd', 'z', 'c', 'f', 'q', 'i', 'k', 'o'], 'fitness_score': 45}
# {'generation': 5, 'genes': ['j', 'j', 'i', 'n', 'd', 'a', 'w', 'q', 'q', 'o'], 'fitness_score': 45}
# {'generation': 5, 'genes': ['a', 'k', 'n', 'o', 'h', 'c', 'l', 'u', 'e', 'x'], 'fitness_score': 45}
# {'generation': 2, 'genes': ['u', 'o', 'b', 't', 'l', 'b', 'z', 'p', 'x', 'm'], 'fitness_score': 46}
# {'generation': 3, 'genes': ['l', 'i', 'g', 'n', 'f', 'z', 'k', 'w', 'c', 'o'], 'fitness_score': 46}
# {'generation': 4, 'genes': ['w', 'a', 'u', 'n', 'x', 'n', 'g', 'i', 'k', 'p'], 'fitness_score': 46}
# {'generation': 3, 'genes': ['o', 'j', 'f', 'q', 'i', 'e', 'p', 's', 'm', 'z'], 'fitness_score': 46}
# {'generation': 4, 'genes': ['n', 'c', 'q', 'w', 'j', 'd', 'a', 'j', 'o', 'g'], 'fitness_score': 47}
# {'generation': 4, 'genes': ['o', 'v', 'y', 'q', 'd', 'a', 'i', 'b', 'd', 'j'], 'fitness_score': 47}
# {'generation': 2, 'genes': ['y', 'm', 'u', 'x', 'g', 'n', 'x', 'o', 'r', 'd'], 'fitness_score': 48}
# {'generation': 1, 'genes': ['d', 'i', 'f', 'n', 'y', 'q', 'h', 'w', 'u', 's'], 'fitness_score': 48}
# {'generation': 2, 'genes': ['x', 'p', 'q', 'a', 'o', 'i', 'f', 'l', 'm', 's'], 'fitness_score': 48}
# {'generation': 3, 'genes': ['g', 'i', 'l', 'a', 'w', 'n', 't', 'c', 'f', 'u'], 'fitness_score': 48}
# {'generation': 3, 'genes': ['o', 'g', 'p', 'w', 'd', 'e', 'n', 'x', 'n', 'j'], 'fitness_score': 48}
# {'generation': 3, 'genes': ['d', 'w', 'q', 'o', 'r', 'j', 'x', 'a', 'h', 'c'], 'fitness_score': 48}
# {'generation': 2, 'genes': ['a', 't', 'j', 'c', 'w', 'x', 'p', 'o', 'i', 'n'], 'fitness_score': 49}
# {'generation': 1, 'genes': ['d', 'k', 'c', 'm', 'x', 'q', 'u', 's', 'y', 'p'], 'fitness_score': 49}
# {'generation': 2, 'genes': ['a', 'c', 's', 'y', 'e', 'f', 'j', 'm', 'k', 'x'], 'fitness_score': 49}
# {'generation': 4, 'genes': ['d', 'c', 't', 'e', 'g', 'w', 'o', 'n', 'n', 'y'], 'fitness_score': 49}
# {'generation': 4, 'genes': ['j', 'r', 'd', 'g', 'w', 'o', 'a', 'p', 'o', 'e'], 'fitness_score': 49}
# {'generation': 4, 'genes': ['q', 'x', 'h', 'n', 'p', 'a', 'd', 'n', 'e', 'c'], 'fitness_score': 49}
# {'generation': 2, 'genes': ['v', 'c', 'n', 'h', 'p', 'o', 'i', 'w', 'f', 's'], 'fitness_score': 49}
# {'generation': 2, 'genes': ['t', 'n', 'v', 'f', 'b', 'x', 'y', 'u', 'z', 'h'], 'fitness_score': 50}

# %%
new_world = World()
new_world.view_world()
for i in range(1000000):
    new_world.iterate()
new_world.view_world()
# Out:
# Iteration: 0
# Successful Mating:  0
# Mating Tried, But Failed:  0
# {'generation': 0, 'genes': ['j', 't', 'a', 'q', 'u', 'w', 'm', 'o', 'h', 'f'], 'fitness_score': 50}
# {'generation': 0, 'genes': ['a', 'm', 'r', 'c', 'k', 'v', 'q', 's', 'x', 'b'], 'fitness_score': 52}
# {'generation': 0, 'genes': ['k', 'e', 'a', 'l', 'w', 'f', 'x', 't', 'h', 'd'], 'fitness_score': 54}
# {'generation': 0, 'genes': ['l', 'g', 'd', 'q', 'r', 'h', 'e', 'z', 'j', 'b'], 'fitness_score': 59}
# {'generation': 0, 'genes': ['t', 'f', 'q', 'o', 'k', 'm', 'v', 'y', 'r', 'i'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['f', 'd', 'b', 'g', 'u', 'm', 's', 'i', 'o', 'n'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['b', 'h', 'k', 'r', 'v', 'f', 'p', 'n', 'x', 'g'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['u', 'd', 'q', 'v', 'c', 'w', 't', 'h', 'j', 'a'], 'fitness_score': 61}
# {'generation': 0, 'genes': ['h', 'k', 'n', 't', 'u', 'p', 'd', 'w', 'g', 'q'], 'fitness_score': 63}
# {'generation': 0, 'genes': ['c', 'p', 'x', 'v', 'n', 's', 'g', 'u', 't', 'a'], 'fitness_score': 65}
# {'generation': 0, 'genes': ['v', 'b', 'o', 'n', 'l', 'u', 'f', 'x', 'c', 's'], 'fitness_score': 66}
# {'generation': 0, 'genes': ['o', 'j', 'e', 'h', 't', 'i', 'b', 'r', 'n', 'm'], 'fitness_score': 66}
# {'generation': 0, 'genes': ['r', 'b', 'd', 'e', 'q', 'o', 'h', 'j', 'g', 'm'], 'fitness_score': 67}
# {'generation': 0, 'genes': ['h', 'y', 'f', 'b', 's', 't', 'q', 'p', 'n', 'w'], 'fitness_score': 68}
# {'generation': 0, 'genes': ['s', 'm', 'x', 'l', 't', 'g', 'c', 'n', 'h', 'd'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['v', 'x', 'k', 'a', 'p', 'o', 'l', 'g', 'n', 'b'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['w', 'n', 'b', 'l', 'p', 'u', 'q', 'c', 'y', 'i'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['y', 'd', 'e', 'q', 'p', 'a', 'j', 'm', 'k', 'n'], 'fitness_score': 74}
# {'generation': 0, 'genes': ['o', 'l', 's', 't', 'g', 'n', 'c', 'r', 'z', 'f'], 'fitness_score': 74}
# {'generation': 0, 'genes': ['v', 'm', 'k', 'h', 'd', 'f', 'y', 'z', 'l', 'b'], 'fitness_score': 75}
# {'generation': 0, 'genes': ['a', 'c', 'v', 'y', 'f', 'z', 'm', 'l', 's', 'w'], 'fitness_score': 78}
# {'generation': 0, 'genes': ['e', 'r', 'i', 'a', 'y', 'k', 'p', 'g', 'x', 'b'], 'fitness_score': 78}
# {'generation': 0, 'genes': ['q', 'o', 'e', 'f', 'a', 'y', 'l', 'v', 's', 'u'], 'fitness_score': 79}
# {'generation': 0, 'genes': ['e', 'q', 'b', 'l', 'o', 'k', 't', 'y', 'w', 'x'], 'fitness_score': 80}
# {'generation': 0, 'genes': ['u', 'q', 'c', 's', 'x', 'o', 'k', 'z', 'h', 'j'], 'fitness_score': 80}
# {'generation': 0, 'genes': ['x', 'n', 'q', 's', 'u', 'r', 'm', 'c', 'b', 'j'], 'fitness_score': 81}
# {'generation': 0, 'genes': ['a', 'm', 'p', 'k', 'v', 'f', 'n', 'y', 'z', 't'], 'fitness_score': 82}
# {'generation': 0, 'genes': ['z', 'r', 't', 'h', 'e', 'k', 'o', 'x', 'b', 'f'], 'fitness_score': 83}
# {'generation': 0, 'genes': ['b', 's', 'l', 'w', 'z', 'i', 'h', 'f', 't', 'd'], 'fitness_score': 83}
# {'generation': 0, 'genes': ['a', 'v', 'i', 's', 'c', 'n', 'e', 'x', 'g', 'l'], 'fitness_score': 84}
# {'generation': 0, 'genes': ['t', 'a', 's', 'v', 'j', 'c', 'k', 'y', 'z', 'e'], 'fitness_score': 84}
# {'generation': 0, 'genes': ['g', 'b', 't', 'y', 'd', 'a', 'u', 'p', 'l', 'w'], 'fitness_score': 85}
# {'generation': 0, 'genes': ['m', 'u', 'g', 't', 'v', 'n', 'f', 'h', 'x', 'j'], 'fitness_score': 87}
# {'generation': 0, 'genes': ['g', 'y', 'h', 'q', 'x', 'f', 'p', 'l', 'c', 't'], 'fitness_score': 88}
# {'generation': 0, 'genes': ['v', 'o', 'y', 'b', 'd', 'j', 'p', 'r', 'x', 'i'], 'fitness_score': 89}
# {'generation': 0, 'genes': ['e', 'w', 'r', 'z', 'g', 'l', 's', 'm', 'p', 't'], 'fitness_score': 89}
# {'generation': 0, 'genes': ['c', 'u', 'y', 'b', 's', 'm', 'g', 'h', 'v', 'i'], 'fitness_score': 91}
# {'generation': 0, 'genes': ['z', 'j', 'r', 'e', 'u', 'c', 'h', 'n', 'x', 'k'], 'fitness_score': 92}
# {'generation': 0, 'genes': ['b', 'c', 'd', 'z', 'x', 'm', 'g', 'w', 'y', 'u'], 'fitness_score': 92}
# {'generation': 0, 'genes': ['u', 'z', 'j', 'g', 'e', 'i', 'f', 'n', 'y', 'c'], 'fitness_score': 92}
# {'generation': 0, 'genes': ['i', 'y', 'c', 'g', 'm', 'h', 'b', 'o', 'w', 'r'], 'fitness_score': 93}
# {'generation': 0, 'genes': ['m', 'q', 'a', 'b', 'x', 'f', 'v', 'y', 'z', 'e'], 'fitness_score': 93}
# {'generation': 0, 'genes': ['q', 'p', 'n', 'y', 'k', 'c', 'l', 'b', 'o', 'r'], 'fitness_score': 95}
# {'generation': 0, 'genes': ['m', 't', 'z', 'a', 'x', 'l', 'u', 'w', 'c', 'p'], 'fitness_score': 97}
# {'generation': 0, 'genes': ['m', 's', 'e', 'h', 'd', 'c', 'i', 'j', 'k', 'z'], 'fitness_score': 98}
# {'generation': 0, 'genes': ['b', 'u', 't', 'd', 'q', 'k', 'c', 'g', 'h', 'w'], 'fitness_score': 98}
# {'generation': 0, 'genes': ['n', 'u', 'w', 'g', 'm', 'p', 'y', 'a', 'v', 's'], 'fitness_score': 99}
# {'generation': 0, 'genes': ['q', 'e', 'g', 'r', 't', 'b', 'd', 'f', 'a', 'z'], 'fitness_score': 102}
# {'generation': 0, 'genes': ['z', 'y', 'l', 'q', 'd', 't', 'x', 'c', 'v', 'p'], 'fitness_score': 103}
# {'generation': 0, 'genes': ['o', 'q', 'y', 'f', 'a', 'l', 'c', 'n', 'b', 'w'], 'fitness_score': 108}
# Iteration: 1000000
# Successful Mating:  10093647
# Mating Tried, But Failed:  38906353
# {'generation': 9, 'genes': ['r', 'c', 'a', 't', 'z', 'g', 'k', 'm', 'o', 'h'], 'fitness_score': 13}
# {'generation': 11, 'genes': ['d', 'p', 'k', 'f', 'm', 'a', 's', 'g', 'l', 'w'], 'fitness_score': 13}
# {'generation': 12, 'genes': ['m', 'n', 'z', 'v', 'o', 'r', 'k', 'j', 'm', 'e'], 'fitness_score': 13}
# {'generation': 13, 'genes': ['f', 'l', 'q', 'k', 'v', 'w', 'm', 'w', 'o', 'n'], 'fitness_score': 13}
# {'generation': 8, 'genes': ['v', 'c', 'g', 'u', 'j', 'f', 'z', 'h', 'd', 'i'], 'fitness_score': 14}
# {'generation': 11, 'genes': ['x', 'g', 'a', 'i', 'r', 's', 'l', 'c', 'k', 'w'], 'fitness_score': 14}
# {'generation': 11, 'genes': ['t', 'd', 'g', 'y', 'w', 'a', 'z', 'o', 'f', 'b'], 'fitness_score': 14}
# {'generation': 11, 'genes': ['e', 'd', 'x', 'r', 'b', 'f', 't', 'i', 'o', 'y'], 'fitness_score': 14}
# {'generation': 6, 'genes': ['v', 'b', 'b', 'w', 'i', 'x', 'z', 'n', 'e', 'o'], 'fitness_score': 15}
# {'generation': 11, 'genes': ['u', 'r', 'm', 'g', 't', 'f', 'v', 'f', 'e', 'a'], 'fitness_score': 15}
# {'generation': 10, 'genes': ['i', 'z', 'r', 'm', 'h', 'r', 'n', 'f', 'v', 'b'], 'fitness_score': 15}
# {'generation': 9, 'genes': ['i', 'p', 's', 'k', 'z', 'z', 'm', 'x', 'q', 'm'], 'fitness_score': 15}
# {'generation': 9, 'genes': ['k', 't', 's', 'r', 'z', 'e', 'd', 'p', 'o', 'x'], 'fitness_score': 15}
# {'generation': 13, 'genes': ['u', 'x', 'q', 'n', 'x', 'k', 't', 'o', 'g', 'n'], 'fitness_score': 15}
# {'generation': 9, 'genes': ['n', 'p', 'm', 'b', 'h', 'w', 'z', 'u', 'd', 'f'], 'fitness_score': 16}
# {'generation': 10, 'genes': ['i', 'p', 'y', 'h', 'z', 'u', 's', 'f', 'v', 'g'], 'fitness_score': 16}
# {'generation': 10, 'genes': ['e', 'g', 'j', 's', 'q', 'r', 'a', 'f', 'n', 'y'], 'fitness_score': 16}
# {'generation': 13, 'genes': ['p', 'w', 'm', 't', 's', 'h', 'n', 'q', 't', 'r'], 'fitness_score': 16}
# {'generation': 11, 'genes': ['o', 'u', 's', 'c', 'm', 'x', 'k', 'o', 't', 'm'], 'fitness_score': 16}
# {'generation': 11, 'genes': ['y', 'f', 'c', 'k', 'r', 'a', 'o', 'b', 'f', 't'], 'fitness_score': 16}
# {'generation': 10, 'genes': ['d', 'f', 'z', 'c', 'v', 'o', 'p', 'y', 'j', 'k'], 'fitness_score': 16}
# {'generation': 10, 'genes': ['m', 'd', 's', 'p', 'n', 'f', 'r', 'z', 'q', 'm'], 'fitness_score': 16}
# {'generation': 11, 'genes': ['k', 'l', 'y', 'n', 'g', 'j', 'd', 'f', 't', 'x'], 'fitness_score': 16}
# {'generation': 10, 'genes': ['p', 'z', 'f', 's', 'd', 'x', 't', 'm', 'z', 'q'], 'fitness_score': 16}
# {'generation': 12, 'genes': ['t', 'm', 'k', 'h', 'v', 'd', 'z', 'b', 'l', 'f'], 'fitness_score': 16}
# {'generation': 11, 'genes': ['e', 'l', 'i', 'd', 'y', 'b', 'z', 'm', 'v', 'k'], 'fitness_score': 16}
# {'generation': 11, 'genes': ['g', 'o', 'c', 'i', 'd', 'j', 'q', 'm', 'n', 'w'], 'fitness_score': 16}
# {'generation': 10, 'genes': ['r', 'p', 'i', 'x', 'z', 'x', 'k', 'q', 'n', 'm'], 'fitness_score': 16}
# {'generation': 7, 'genes': ['h', 'n', 'w', 'y', 'c', 'v', 'c', 't', 'n', 'v'], 'fitness_score': 17}
# {'generation': 9, 'genes': ['u', 'n', 'g', 'a', 'q', 'f', 'b', 'v', 'h', 'n'], 'fitness_score': 17}
# {'generation': 11, 'genes': ['p', 'm', 'a', 'c', 'l', 'o', 'i', 'k', 'h', 'y'], 'fitness_score': 17}
# {'generation': 10, 'genes': ['a', 'j', 'z', 's', 'o', 'l', 'a', 'x', 'o', 'f'], 'fitness_score': 17}
# {'generation': 12, 'genes': ['r', 'k', 'q', 'i', 'c', 'x', 'j', 'g', 'w', 's'], 'fitness_score': 17}
# {'generation': 10, 'genes': ['o', 'f', 'v', 'b', 'f', 'd', 'k', 'v', 'e', 'w'], 'fitness_score': 17}
# {'generation': 11, 'genes': ['w', 'v', 'z', 'e', 'i', 'j', 'q', 'f', 'f', 'g'], 'fitness_score': 17}
# {'generation': 12, 'genes': ['k', 'h', 'n', 'l', 's', 't', 'y', 'u', 'j', 'q'], 'fitness_score': 17}
# {'generation': 9, 'genes': ['q', 'e', 'f', 'e', 'j', 's', 'r', 'g', 'm', 'm'], 'fitness_score': 17}
# {'generation': 13, 'genes': ['q', 'k', 'n', 'm', 'w', 'j', 'w', 'r', 'c', 'u'], 'fitness_score': 17}
# {'generation': 11, 'genes': ['p', 'c', 'l', 'a', 'o', 'g', 'm', 't', 'd', 'i'], 'fitness_score': 17}
# {'generation': 13, 'genes': ['i', 'c', 'x', 'j', 'd', 'm', 'b', 'g', 'z', 'x'], 'fitness_score': 17}
# {'generation': 9, 'genes': ['m', 'z', 'r', 'k', 'o', 'n', 'f', 'p', 'x', 'v'], 'fitness_score': 17}
# {'generation': 11, 'genes': ['f', 'o', 'f', 'l', 'm', 'b', 'q', 'a', 'v', 'r'], 'fitness_score': 17}
# {'generation': 12, 'genes': ['g', 'j', 'y', 'z', 's', 'm', 'w', 'c', 'b', 'v'], 'fitness_score': 17}
# {'generation': 10, 'genes': ['k', 'p', 'u', 'x', 'q', 's', 'o', 'r', 'z', 'z'], 'fitness_score': 17}
# {'generation': 11, 'genes': ['j', 'g', 'v', 'l', 'o', 'x', 'q', 'g', 't', 'b'], 'fitness_score': 17}
# {'generation': 12, 'genes': ['v', 'a', 'n', 'z', 'c', 'm', 'o', 'q', 'w', 'y'], 'fitness_score': 17}
# {'generation': 12, 'genes': ['m', 'v', 'r', 'g', 'm', 'p', 'o', 'a', 'd', 'u'], 'fitness_score': 17}
# {'generation': 12, 'genes': ['w', 'u', 'o', 'g', 't', 'i', 'l', 'q', 'x', 'm'], 'fitness_score': 17}
# {'generation': 12, 'genes': ['t', 'i', 'x', 'p', 'f', 'd', 'd', 'y', 'w', 'a'], 'fitness_score': 17}
# {'generation': 8, 'genes': ['t', 'c', 'n', 'd', 'f', 'f', 's', 'm', 'a', 'w'], 'fitness_score': 18}

# %% [markdown]
# # Automated Test confirms there is some issues with the shuffling system and the logic of my world. Organisms must die after 3-5 geerations. maybe will make this dying random. This is sad. Even in a computer generated world, death is inevident, death is neccessity
