# %% [markdown]
# <a href="https://www.kaggle.com/code/takrimulalam/evolve-your-organisms-ipynb?scriptVersionId=254224232" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # This NoteBook is now public. Anyone interested and want to improve or resolve my issues can fork it and work on it. Just let me know you findings. Thanks in advance

# %% [markdown]
# ## Import Section

# %%
import string
import random

# %% [markdown]
# ## Defining the ideal condition to exist in universe for an organism(The gene we want as the output)
# ## "helloworld" for this research

# %%
total_possible_genes = string.ascii_lowercase
ideal_genes_to_survive = "helloworld"

# %% [markdown]
# ## Creating Organisms

# %%
class Organism:
    def __init__(self,gene_length=10,generation=0):
        self.gene_length = gene_length
        self.genes = random.sample(total_possible_genes, gene_length)
        self.mutated_gene_length = random.randint(0,5)
        self.generation = generation
        self.fitness_score = [abs(ord(i)-ord(j)) for i,j in zip(ideal_genes_to_survive, self.genes)]
        
    def mate(self,other):
        if (self.gene_length != other.gene_length) or (self.generation != other.generation):
            return "mating impossible"
        else:
            inherited_gene_length = self.gene_length - self.mutated_gene_length
            inherited_genes = random.sample(self.genes+other.genes,inherited_gene_length)
            possible_mutated_genes =  set(total_possible_genes) - (set(self.genes)|set(other.genes))
            mutated_genes = random.sample(list(possible_mutated_genes),self.mutated_gene_length)
            child = Organism(gene_length=self.gene_length,generation=(self.generation+1))
            child.genes = inherited_genes + mutated_genes
            random.shuffle(child.genes)
            return child
            
    def get_details(self):
        return {'generation' : self.generation, 'genes' : self.genes, 'fitness_score' : sum(self.fitness_score)}
    
    def __str__(self):
        return "".join(self.genes)

# %% [markdown]
# # Testing organisms and their mating

# %%
test_organism = Organism()
another_test_organism = Organism()
print(test_organism.get_details())
print(another_test_organism.get_details())
child_organism = test_organism.mate(another_test_organism)
print(child_organism.get_details())
# Out:
# {'generation': 0, 'genes': ['l', 'w', 'd', 'f', 'x', 'g', 'j', 'q', 'e', 'i'], 'fitness_score': 79}
# {'generation': 0, 'genes': ['q', 'f', 'm', 'o', 'c', 'z', 'd', 'a', 'k', 'j'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['d', 'm', 'q', 'j', 'i', 'k', 'a', 'o', 'w', 'c'], 'fitness_score': 64}

# %% [markdown]
# ## Organism conditions are nearly done, Let's procced to create world where organisms can evolve

# %%
class World:
    def __init__(self,population=50,fixed=True):
        self.fixed = fixed
        self.iteration = 0
        self.mated = 0
        self.failed_mate = 0
        self.population = population
        self.organisms = []
        for _ in range(population):
            self.organisms.append(Organism())
        self.organisms = sorted(self.organisms, key=lambda org: sum(org.fitness_score))
    def iterate(self):
        self.iteration += 1
        for i in range(len(self.organisms)-1):
            child = self.organisms[i].mate(self.organisms[i+1])
            if child != "mating impossible":
                self.organisms.append(child)
                self.mated += 1
            else:
                self.failed_mate += 1
        
        if self.fixed == True:
            self.organisms = sorted(self.organisms, key=lambda org: sum(org.fitness_score))[:self.population]
        else:
            self.organisms = sorted(self.organisms, key=lambda org: sum(org.fitness_score))
            
    def view_world(self):
        print("Iteration:", self.iteration)
        print("Successful Mating: ", self.mated)
        print("Mating Tried, But Failed: ", self.failed_mate)
        for org in self.organisms:
            print(org.get_details())

# %%
test_world = World()
test_world.view_world()
# Out:
# Iteration: 0
# Successful Mating:  0
# Mating Tried, But Failed:  0
# {'generation': 0, 'genes': ['q', 'd', 'k', 'm', 'p', 'v', 'o', 'x', 'e', 'c'], 'fitness_score': 28}
# {'generation': 0, 'genes': ['t', 'h', 'i', 'b', 'm', 'q', 'n', 'w', 'l', 'a'], 'fitness_score': 45}
# {'generation': 0, 'genes': ['f', 'e', 'n', 'k', 'a', 'q', 't', 'd', 'i', 'c'], 'fitness_score': 48}
# {'generation': 0, 'genes': ['m', 'b', 'f', 'j', 'n', 'p', 't', 'h', 'i', 'k'], 'fitness_score': 49}
# {'generation': 0, 'genes': ['l', 'h', 'p', 'c', 'i', 't', 'o', 'q', 'v', 'n'], 'fitness_score': 50}
# {'generation': 0, 'genes': ['q', 'n', 'm', 's', 'r', 'u', 'l', 'x', 'v', 'a'], 'fitness_score': 53}
# {'generation': 0, 'genes': ['d', 'v', 'l', 'p', 'x', 'y', 'o', 't', 'r', 'm'], 'fitness_score': 53}
# {'generation': 0, 'genes': ['n', 'b', 'x', 'l', 'f', 's', 'p', 'w', 'a', 'g'], 'fitness_score': 54}
# {'generation': 0, 'genes': ['t', 'l', 'i', 'k', 'q', 'z', 'j', 's', 'w', 'o'], 'fitness_score': 56}
# {'generation': 0, 'genes': ['e', 'o', 'l', 'j', 's', 'p', 'f', 'w', 'v', 'n'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['g', 's', 'k', 'z', 'j', 't', 'e', 'v', 'f', 'h'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['k', 'x', 'n', 'r', 'u', 'w', 'q', 'y', 'i', 's'], 'fitness_score': 63}
# {'generation': 0, 'genes': ['r', 'a', 'p', 'v', 'o', 'i', 'c', 'm', 'j', 'g'], 'fitness_score': 64}
# {'generation': 0, 'genes': ['c', 't', 'k', 'i', 'x', 'v', 'y', 'g', 'p', 'j'], 'fitness_score': 65}
# {'generation': 0, 'genes': ['s', 'r', 'j', 'i', 'l', 'z', 'n', 'o', 't', 'v'], 'fitness_score': 65}
# {'generation': 0, 'genes': ['c', 'n', 't', 'r', 'k', 'x', 'b', 'y', 'w', 'a'], 'fitness_score': 67}
# {'generation': 0, 'genes': ['r', 'g', 'u', 'v', 'x', 'y', 'n', 'l', 'a', 'm'], 'fitness_score': 69}
# {'generation': 0, 'genes': ['j', 'r', 'x', 'd', 's', 'q', 'u', 'n', 'a', 'h'], 'fitness_score': 70}
# {'generation': 0, 'genes': ['d', 'f', 't', 'h', 'g', 'z', 'c', 'y', 'r', 'v'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['j', 'x', 'b', 'i', 'k', 'e', 'p', 'o', 't', 'a'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['o', 'z', 'p', 'd', 'l', 'e', 'k', 'r', 'm', 'i'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['o', 'c', 'v', 'r', 'w', 'y', 'f', 'b', 'z', 'd'], 'fitness_score': 74}
# {'generation': 0, 'genes': ['r', 'c', 'i', 't', 'z', 'm', 'n', 'a', 'd', 'k'], 'fitness_score': 77}
# {'generation': 0, 'genes': ['v', 'h', 'f', 'i', 'k', 'd', 'x', 's', 'g', 'q'], 'fitness_score': 77}
# {'generation': 0, 'genes': ['p', 'b', 'u', 'a', 'm', 'n', 'c', 's', 'k', 'z'], 'fitness_score': 78}
# {'generation': 0, 'genes': ['d', 'p', 't', 'f', 'z', 'n', 'h', 'x', 'c', 'k'], 'fitness_score': 78}
# {'generation': 0, 'genes': ['l', 'o', 'w', 'k', 'z', 'f', 'v', 'h', 'u', 'd'], 'fitness_score': 80}
# {'generation': 0, 'genes': ['k', 'v', 'x', 'm', 'w', 'i', 'r', 'b', 'g', 'e'], 'fitness_score': 80}
# {'generation': 0, 'genes': ['d', 's', 'x', 'e', 'm', 'h', 'l', 'u', 'k', 'w'], 'fitness_score': 80}
# {'generation': 0, 'genes': ['y', 'q', 'u', 'd', 'e', 'z', 'o', 't', 'w', 'l'], 'fitness_score': 80}
# {'generation': 0, 'genes': ['k', 'n', 'v', 'r', 'w', 'a', 'm', 'q', 'x', 'l'], 'fitness_score': 81}
# {'generation': 0, 'genes': ['j', 's', 'k', 'o', 'f', 'h', 'v', 'g', 'q', 't'], 'fitness_score': 83}
# {'generation': 0, 'genes': ['j', 'l', 'y', 'u', 'd', 'e', 'm', 'k', 'b', 'i'], 'fitness_score': 84}
# {'generation': 0, 'genes': ['v', 'i', 'q', 'g', 'w', 's', 'h', 'l', 'a', 'z'], 'fitness_score': 86}
# {'generation': 0, 'genes': ['u', 'g', 'n', 'b', 'f', 'i', 'v', 'c', 't', 'k'], 'fitness_score': 87}
# {'generation': 0, 'genes': ['w', 'm', 'n', 's', 'j', 'o', 'u', 'c', 'z', 'l'], 'fitness_score': 88}
# {'generation': 0, 'genes': ['q', 'c', 'y', 'd', 'u', 'e', 'm', 'w', 'f', 'x'], 'fitness_score': 89}
# {'generation': 0, 'genes': ['m', 'v', 'f', 'o', 'x', 'g', 'w', 'q', 'c', 'u'], 'fitness_score': 91}
# {'generation': 0, 'genes': ['o', 'r', 'h', 'm', 'l', 'b', 's', 'g', 'f', 'y'], 'fitness_score': 91}
# {'generation': 0, 'genes': ['b', 'x', 'n', 'j', 'c', 'e', 'v', 'q', 'r', 'w'], 'fitness_score': 92}
# {'generation': 0, 'genes': ['j', 'y', 'w', 'l', 'd', 't', 'f', 'i', 'z', 's'], 'fitness_score': 94}
# {'generation': 0, 'genes': ['k', 'o', 'q', 'a', 'z', 'c', 'p', 'j', 'e', 'w'], 'fitness_score': 95}
# {'generation': 0, 'genes': ['w', 's', 'x', 'q', 'a', 'b', 'u', 'j', 'l', 'i'], 'fitness_score': 100}
# {'generation': 0, 'genes': ['e', 'z', 'n', 'b', 'h', 'f', 'l', 'c', 'y', 'o'], 'fitness_score': 102}
# {'generation': 0, 'genes': ['x', 'u', 'w', 'm', 'p', 'h', 'c', 'z', 'd', 'r'], 'fitness_score': 102}
# {'generation': 0, 'genes': ['s', 'm', 'z', 'i', 'c', 'l', 'k', 'a', 'f', 'u'], 'fitness_score': 103}
# {'generation': 0, 'genes': ['t', 'z', 'a', 'j', 'k', 'r', 'w', 'g', 'y', 'v'], 'fitness_score': 105}
# {'generation': 0, 'genes': ['i', 'y', 't', 'l', 'a', 'b', 'p', 'e', 'u', 'w'], 'fitness_score': 106}
# {'generation': 0, 'genes': ['q', 'w', 'x', 'd', 'g', 'k', 'z', 'j', 'p', 't'], 'fitness_score': 106}
# {'generation': 0, 'genes': ['s', 'w', 'v', 'c', 'y', 'm', 'e', 'a', 't', 'h'], 'fitness_score': 107}

# %%
test_world.iterate()
test_world.view_world()
# Out:
# Iteration: 1
# Successful Mating:  49
# Mating Tried, But Failed:  0
# {'generation': 0, 'genes': ['q', 'd', 'k', 'm', 'p', 'v', 'o', 'x', 'e', 'c'], 'fitness_score': 28}
# {'generation': 1, 'genes': ['t', 'h', 'm', 'b', 'c', 'b', 'p', 'e', 'g', 'd'], 'fitness_score': 43}
# {'generation': 0, 'genes': ['t', 'h', 'i', 'b', 'm', 'q', 'n', 'w', 'l', 'a'], 'fitness_score': 45}
# {'generation': 0, 'genes': ['f', 'e', 'n', 'k', 'a', 'q', 't', 'd', 'i', 'c'], 'fitness_score': 48}
# {'generation': 0, 'genes': ['m', 'b', 'f', 'j', 'n', 'p', 't', 'h', 'i', 'k'], 'fitness_score': 49}
# {'generation': 1, 'genes': ['j', 'h', 'h', 'p', 't', 'i', 'k', 't', 'i', 'p'], 'fitness_score': 49}
# {'generation': 0, 'genes': ['l', 'h', 'p', 'c', 'i', 't', 'o', 'q', 'v', 'n'], 'fitness_score': 50}
# {'generation': 1, 'genes': ['g', 'b', 'a', 'o', 'r', 'h', 'z', 'w', 'l', 'n'], 'fitness_score': 51}
# {'generation': 0, 'genes': ['q', 'n', 'm', 's', 'r', 'u', 'l', 'x', 'v', 'a'], 'fitness_score': 53}
# {'generation': 0, 'genes': ['d', 'v', 'l', 'p', 'x', 'y', 'o', 't', 'r', 'm'], 'fitness_score': 53}
# {'generation': 0, 'genes': ['n', 'b', 'x', 'l', 'f', 's', 'p', 'w', 'a', 'g'], 'fitness_score': 54}
# {'generation': 0, 'genes': ['t', 'l', 'i', 'k', 'q', 'z', 'j', 's', 'w', 'o'], 'fitness_score': 56}
# {'generation': 1, 'genes': ['g', 'u', 'v', 'l', 'x', 'n', 's', 'd', 'i', 'd'], 'fitness_score': 56}
# {'generation': 1, 'genes': ['f', 'k', 'd', 'o', 'i', 'l', 'z', 'k', 'r', 'j'], 'fitness_score': 57}
# {'generation': 1, 'genes': ['d', 'v', 'y', 'z', 's', 'c', 'z', 'w', 'b', 't'], 'fitness_score': 59}
# {'generation': 0, 'genes': ['e', 'o', 'l', 'j', 's', 'p', 'f', 'w', 'v', 'n'], 'fitness_score': 60}
# {'generation': 1, 'genes': ['z', 'f', 'u', 'r', 'n', 'o', 's', 'j', 'v', 'c'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['g', 's', 'k', 'z', 'j', 't', 'e', 'v', 'f', 'h'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['k', 'x', 'n', 'r', 'u', 'w', 'q', 'y', 'i', 's'], 'fitness_score': 63}
# {'generation': 0, 'genes': ['r', 'a', 'p', 'v', 'o', 'i', 'c', 'm', 'j', 'g'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['z', 'u', 's', 'i', 'j', 'v', 'c', 't', 'c', 'l'], 'fitness_score': 64}
# {'generation': 0, 'genes': ['c', 't', 'k', 'i', 'x', 'v', 'y', 'g', 'p', 'j'], 'fitness_score': 65}
# {'generation': 0, 'genes': ['s', 'r', 'j', 'i', 'l', 'z', 'n', 'o', 't', 'v'], 'fitness_score': 65}
# {'generation': 1, 'genes': ['f', 'w', 'a', 'z', 'j', 'b', 'g', 'q', 'd', 'r'], 'fitness_score': 66}
# {'generation': 1, 'genes': ['d', 'k', 'e', 'u', 'g', 'p', 'q', 'f', 'r', 'x'], 'fitness_score': 66}
# {'generation': 1, 'genes': ['x', 'k', 'q', 'h', 'i', 'w', 'p', 'a', 'c', 'q'], 'fitness_score': 66}
# {'generation': 0, 'genes': ['c', 'n', 't', 'r', 'k', 'x', 'b', 'y', 'w', 'a'], 'fitness_score': 67}
# {'generation': 1, 'genes': ['g', 'v', 'x', 'q', 'y', 'd', 'i', 'j', 'y', 'h'], 'fitness_score': 67}
# {'generation': 1, 'genes': ['n', 'j', 'g', 'r', 'q', 'o', 'm', 'p', 'i', 'w'], 'fitness_score': 68}
# {'generation': 0, 'genes': ['r', 'g', 'u', 'v', 'x', 'y', 'n', 'l', 'a', 'm'], 'fitness_score': 69}
# {'generation': 1, 'genes': ['o', 'g', 't', 'w', 'y', 'p', 'v', 'r', 'b', 'd'], 'fitness_score': 69}
# {'generation': 1, 'genes': ['v', 'i', 'e', 'f', 'k', 's', 'd', 'a', 'k', 'c'], 'fitness_score': 69}
# {'generation': 0, 'genes': ['j', 'r', 'x', 'd', 's', 'q', 'u', 'n', 'a', 'h'], 'fitness_score': 70}
# {'generation': 1, 'genes': ['s', 'q', 'c', 'v', 'f', 'x', 'b', 'g', 'n', 'b'], 'fitness_score': 70}
# {'generation': 0, 'genes': ['d', 'f', 't', 'h', 'g', 'z', 'c', 'y', 'r', 'v'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['j', 'x', 'b', 'i', 'k', 'e', 'p', 'o', 't', 'a'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['o', 'z', 'p', 'd', 'l', 'e', 'k', 'r', 'm', 'i'], 'fitness_score': 71}
# {'generation': 1, 'genes': ['u', 'd', 'o', 'r', 'b', 'h', 'c', 'p', 'm', 'l'], 'fitness_score': 72}
# {'generation': 1, 'genes': ['c', 'i', 'k', 'j', 'm', 'l', 'n', 'u', 'r', 'g'], 'fitness_score': 72}
# {'generation': 1, 'genes': ['r', 'b', 'o', 's', 'q', 'u', 'k', 'w', 'p', 'e'], 'fitness_score': 73}
# {'generation': 1, 'genes': ['m', 'f', 'l', 'h', 'h', 'w', 'k', 'k', 'd', 'q'], 'fitness_score': 73}
# {'generation': 0, 'genes': ['o', 'c', 'v', 'r', 'w', 'y', 'f', 'b', 'z', 'd'], 'fitness_score': 74}
# {'generation': 1, 'genes': ['i', 'z', 'm', 'x', 'q', 'd', 't', 'i', 'k', 'f'], 'fitness_score': 74}
# {'generation': 1, 'genes': ['v', 't', 'f', 'h', 'q', 'e', 'm', 'i', 'd', 'y'], 'fitness_score': 75}
# {'generation': 1, 'genes': ['o', 'r', 'k', 'i', 's', 'v', 'i', 'j', 'c', 'j'], 'fitness_score': 75}
# {'generation': 1, 'genes': ['z', 'c', 't', 'a', 'o', 'h', 'j', 'e', 'b', 'v'], 'fitness_score': 75}
# {'generation': 0, 'genes': ['r', 'c', 'i', 't', 'z', 'm', 'n', 'a', 'd', 'k'], 'fitness_score': 77}
# {'generation': 0, 'genes': ['v', 'h', 'f', 'i', 'k', 'd', 'x', 's', 'g', 'q'], 'fitness_score': 77}
# {'generation': 0, 'genes': ['p', 'b', 'u', 'a', 'm', 'n', 'c', 's', 'k', 'z'], 'fitness_score': 78}
# {'generation': 0, 'genes': ['d', 'p', 't', 'f', 'z', 'n', 'h', 'x', 'c', 'k'], 'fitness_score': 78}

# %%
test_world.iterate()
test_world.view_world()
# Out:
# Iteration: 2
# Successful Mating:  74
# Mating Tried, But Failed:  24
# {'generation': 0, 'genes': ['q', 'd', 'k', 'm', 'p', 'v', 'o', 'x', 'e', 'c'], 'fitness_score': 28}
# {'generation': 1, 'genes': ['t', 'h', 'm', 'b', 'c', 'b', 'p', 'e', 'g', 'd'], 'fitness_score': 43}
# {'generation': 0, 'genes': ['t', 'h', 'i', 'b', 'm', 'q', 'n', 'w', 'l', 'a'], 'fitness_score': 45}
# {'generation': 0, 'genes': ['f', 'e', 'n', 'k', 'a', 'q', 't', 'd', 'i', 'c'], 'fitness_score': 48}
# {'generation': 0, 'genes': ['m', 'b', 'f', 'j', 'n', 'p', 't', 'h', 'i', 'k'], 'fitness_score': 49}
# {'generation': 1, 'genes': ['j', 'h', 'h', 'p', 't', 'i', 'k', 't', 'i', 'p'], 'fitness_score': 49}
# {'generation': 0, 'genes': ['l', 'h', 'p', 'c', 'i', 't', 'o', 'q', 'v', 'n'], 'fitness_score': 50}
# {'generation': 2, 'genes': ['u', 'v', 'f', 'j', 'n', 'o', 'm', 'j', 'q', 'r'], 'fitness_score': 50}
# {'generation': 1, 'genes': ['g', 'b', 'a', 'o', 'r', 'h', 'z', 'w', 'l', 'n'], 'fitness_score': 51}
# {'generation': 0, 'genes': ['q', 'n', 'm', 's', 'r', 'u', 'l', 'x', 'v', 'a'], 'fitness_score': 53}
# {'generation': 0, 'genes': ['d', 'v', 'l', 'p', 'x', 'y', 'o', 't', 'r', 'm'], 'fitness_score': 53}
# {'generation': 0, 'genes': ['n', 'b', 'x', 'l', 'f', 's', 'p', 'w', 'a', 'g'], 'fitness_score': 54}
# {'generation': 0, 'genes': ['t', 'l', 'i', 'k', 'q', 'z', 'j', 's', 'w', 'o'], 'fitness_score': 56}
# {'generation': 1, 'genes': ['g', 'u', 'v', 'l', 'x', 'n', 's', 'd', 'i', 'd'], 'fitness_score': 56}
# {'generation': 1, 'genes': ['f', 'k', 'd', 'o', 'i', 'l', 'z', 'k', 'r', 'j'], 'fitness_score': 57}
# {'generation': 1, 'genes': ['d', 'v', 'y', 'z', 's', 'c', 'z', 'w', 'b', 't'], 'fitness_score': 59}
# {'generation': 2, 'genes': ['n', 'u', 'a', 'i', 'p', 't', 'v', 'i', 'x', 'v'], 'fitness_score': 59}
# {'generation': 0, 'genes': ['e', 'o', 'l', 'j', 's', 'p', 'f', 'w', 'v', 'n'], 'fitness_score': 60}
# {'generation': 1, 'genes': ['z', 'f', 'u', 'r', 'n', 'o', 's', 'j', 'v', 'c'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['g', 's', 'k', 'z', 'j', 't', 'e', 'v', 'f', 'h'], 'fitness_score': 62}
# {'generation': 1, 'genes': ['s', 'd', 'x', 'n', 'p', 'z', 'r', 'q', 'c', 'm'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['k', 'x', 'n', 'r', 'u', 'w', 'q', 'y', 'i', 's'], 'fitness_score': 63}
# {'generation': 0, 'genes': ['r', 'a', 'p', 'v', 'o', 'i', 'c', 'm', 'j', 'g'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['z', 'u', 's', 'i', 'j', 'v', 'c', 't', 'c', 'l'], 'fitness_score': 64}
# {'generation': 2, 'genes': ['e', 'd', 'q', 'z', 'x', 'k', 'r', 'f', 'f', 'u'], 'fitness_score': 64}
# {'generation': 2, 'genes': ['j', 'x', 'z', 'd', 't', 'b', 'h', 'r', 'o', 'm'], 'fitness_score': 64}
# {'generation': 0, 'genes': ['c', 't', 'k', 'i', 'x', 'v', 'y', 'g', 'p', 'j'], 'fitness_score': 65}
# {'generation': 0, 'genes': ['s', 'r', 'j', 'i', 'l', 'z', 'n', 'o', 't', 'v'], 'fitness_score': 65}
# {'generation': 1, 'genes': ['f', 'w', 'a', 'z', 'j', 'b', 'g', 'q', 'd', 'r'], 'fitness_score': 66}
# {'generation': 1, 'genes': ['d', 'k', 'e', 'u', 'g', 'p', 'q', 'f', 'r', 'x'], 'fitness_score': 66}
# {'generation': 1, 'genes': ['x', 'k', 'q', 'h', 'i', 'w', 'p', 'a', 'c', 'q'], 'fitness_score': 66}
# {'generation': 0, 'genes': ['c', 'n', 't', 'r', 'k', 'x', 'b', 'y', 'w', 'a'], 'fitness_score': 67}
# {'generation': 1, 'genes': ['g', 'v', 'x', 'q', 'y', 'd', 'i', 'j', 'y', 'h'], 'fitness_score': 67}
# {'generation': 2, 'genes': ['v', 'j', 'o', 'l', 't', 's', 'r', 'a', 'n', 'x'], 'fitness_score': 67}
# {'generation': 1, 'genes': ['x', 'n', 'p', 'e', 'j', 'z', 'i', 'y', 'o', 'v'], 'fitness_score': 67}
# {'generation': 1, 'genes': ['n', 'j', 'g', 'r', 'q', 'o', 'm', 'p', 'i', 'w'], 'fitness_score': 68}
# {'generation': 2, 'genes': ['m', 'q', 'u', 'u', 'p', 'a', 'k', 'r', 'f', 'y'], 'fitness_score': 68}
# {'generation': 0, 'genes': ['r', 'g', 'u', 'v', 'x', 'y', 'n', 'l', 'a', 'm'], 'fitness_score': 69}
# {'generation': 1, 'genes': ['o', 'g', 't', 'w', 'y', 'p', 'v', 'r', 'b', 'd'], 'fitness_score': 69}
# {'generation': 1, 'genes': ['v', 'i', 'e', 'f', 'k', 's', 'd', 'a', 'k', 'c'], 'fitness_score': 69}
# {'generation': 2, 'genes': ['g', 'x', 'j', 'i', 'l', 'y', 'i', 'q', 'm', 'g'], 'fitness_score': 69}
# {'generation': 0, 'genes': ['j', 'r', 'x', 'd', 's', 'q', 'u', 'n', 'a', 'h'], 'fitness_score': 70}
# {'generation': 1, 'genes': ['s', 'q', 'c', 'v', 'f', 'x', 'b', 'g', 'n', 'b'], 'fitness_score': 70}
# {'generation': 0, 'genes': ['d', 'f', 't', 'h', 'g', 'z', 'c', 'y', 'r', 'v'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['j', 'x', 'b', 'i', 'k', 'e', 'p', 'o', 't', 'a'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['o', 'z', 'p', 'd', 'l', 'e', 'k', 'r', 'm', 'i'], 'fitness_score': 71}
# {'generation': 1, 'genes': ['u', 'd', 'o', 'r', 'b', 'h', 'c', 'p', 'm', 'l'], 'fitness_score': 72}
# {'generation': 1, 'genes': ['c', 'i', 'k', 'j', 'm', 'l', 'n', 'u', 'r', 'g'], 'fitness_score': 72}
# {'generation': 1, 'genes': ['r', 'b', 'o', 's', 'q', 'u', 'k', 'w', 'p', 'e'], 'fitness_score': 73}
# {'generation': 1, 'genes': ['m', 'f', 'l', 'h', 'h', 'w', 'k', 'k', 'd', 'q'], 'fitness_score': 73}

# %%
test_world.iterate()
test_world.view_world()
# Out:
# Iteration: 3
# Successful Mating:  93
# Mating Tried, But Failed:  54
# {'generation': 0, 'genes': ['q', 'd', 'k', 'm', 'p', 'v', 'o', 'x', 'e', 'c'], 'fitness_score': 28}
# {'generation': 1, 'genes': ['t', 'h', 'm', 'b', 'c', 'b', 'p', 'e', 'g', 'd'], 'fitness_score': 43}
# {'generation': 0, 'genes': ['t', 'h', 'i', 'b', 'm', 'q', 'n', 'w', 'l', 'a'], 'fitness_score': 45}
# {'generation': 0, 'genes': ['f', 'e', 'n', 'k', 'a', 'q', 't', 'd', 'i', 'c'], 'fitness_score': 48}
# {'generation': 0, 'genes': ['m', 'b', 'f', 'j', 'n', 'p', 't', 'h', 'i', 'k'], 'fitness_score': 49}
# {'generation': 1, 'genes': ['j', 'h', 'h', 'p', 't', 'i', 'k', 't', 'i', 'p'], 'fitness_score': 49}
# {'generation': 0, 'genes': ['l', 'h', 'p', 'c', 'i', 't', 'o', 'q', 'v', 'n'], 'fitness_score': 50}
# {'generation': 2, 'genes': ['u', 'v', 'f', 'j', 'n', 'o', 'm', 'j', 'q', 'r'], 'fitness_score': 50}
# {'generation': 1, 'genes': ['g', 'b', 'a', 'o', 'r', 'h', 'z', 'w', 'l', 'n'], 'fitness_score': 51}
# {'generation': 0, 'genes': ['q', 'n', 'm', 's', 'r', 'u', 'l', 'x', 'v', 'a'], 'fitness_score': 53}
# {'generation': 0, 'genes': ['d', 'v', 'l', 'p', 'x', 'y', 'o', 't', 'r', 'm'], 'fitness_score': 53}
# {'generation': 0, 'genes': ['n', 'b', 'x', 'l', 'f', 's', 'p', 'w', 'a', 'g'], 'fitness_score': 54}
# {'generation': 1, 'genes': ['i', 'u', 'g', 'k', 'z', 'l', 'm', 'i', 'e', 'w'], 'fitness_score': 55}
# {'generation': 0, 'genes': ['t', 'l', 'i', 'k', 'q', 'z', 'j', 's', 'w', 'o'], 'fitness_score': 56}
# {'generation': 1, 'genes': ['g', 'u', 'v', 'l', 'x', 'n', 's', 'd', 'i', 'd'], 'fitness_score': 56}
# {'generation': 1, 'genes': ['f', 'k', 'd', 'o', 'i', 'l', 'z', 'k', 'r', 'j'], 'fitness_score': 57}
# {'generation': 1, 'genes': ['d', 'v', 'y', 'z', 's', 'c', 'z', 'w', 'b', 't'], 'fitness_score': 59}
# {'generation': 2, 'genes': ['n', 'u', 'a', 'i', 'p', 't', 'v', 'i', 'x', 'v'], 'fitness_score': 59}
# {'generation': 1, 'genes': ['k', 'v', 'a', 'w', 'h', 'e', 'b', 'k', 'g', 'o'], 'fitness_score': 59}
# {'generation': 0, 'genes': ['e', 'o', 'l', 'j', 's', 'p', 'f', 'w', 'v', 'n'], 'fitness_score': 60}
# {'generation': 1, 'genes': ['z', 'f', 'u', 'r', 'n', 'o', 's', 'j', 'v', 'c'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['g', 's', 'k', 'z', 'j', 't', 'e', 'v', 'f', 'h'], 'fitness_score': 62}
# {'generation': 1, 'genes': ['s', 'd', 'x', 'n', 'p', 'z', 'r', 'q', 'c', 'm'], 'fitness_score': 62}
# {'generation': 2, 'genes': ['q', 'f', 'i', 'n', 'z', 'y', 'l', 'r', 'u', 'j'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['k', 'x', 'n', 'r', 'u', 'w', 'q', 'y', 'i', 's'], 'fitness_score': 63}
# {'generation': 0, 'genes': ['r', 'a', 'p', 'v', 'o', 'i', 'c', 'm', 'j', 'g'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['z', 'u', 's', 'i', 'j', 'v', 'c', 't', 'c', 'l'], 'fitness_score': 64}
# {'generation': 2, 'genes': ['e', 'd', 'q', 'z', 'x', 'k', 'r', 'f', 'f', 'u'], 'fitness_score': 64}
# {'generation': 2, 'genes': ['j', 'x', 'z', 'd', 't', 'b', 'h', 'r', 'o', 'm'], 'fitness_score': 64}
# {'generation': 3, 'genes': ['r', 'd', 'z', 'r', 'j', 'k', 'q', 'u', 'f', 'x'], 'fitness_score': 64}
# {'generation': 0, 'genes': ['c', 't', 'k', 'i', 'x', 'v', 'y', 'g', 'p', 'j'], 'fitness_score': 65}
# {'generation': 0, 'genes': ['s', 'r', 'j', 'i', 'l', 'z', 'n', 'o', 't', 'v'], 'fitness_score': 65}
# {'generation': 2, 'genes': ['q', 'i', 'o', 's', 'g', 'j', 'k', 'r', 'l', 'h'], 'fitness_score': 65}
# {'generation': 1, 'genes': ['f', 'w', 'a', 'z', 'j', 'b', 'g', 'q', 'd', 'r'], 'fitness_score': 66}
# {'generation': 1, 'genes': ['d', 'k', 'e', 'u', 'g', 'p', 'q', 'f', 'r', 'x'], 'fitness_score': 66}
# {'generation': 1, 'genes': ['x', 'k', 'q', 'h', 'i', 'w', 'p', 'a', 'c', 'q'], 'fitness_score': 66}
# {'generation': 0, 'genes': ['c', 'n', 't', 'r', 'k', 'x', 'b', 'y', 'w', 'a'], 'fitness_score': 67}
# {'generation': 1, 'genes': ['g', 'v', 'x', 'q', 'y', 'd', 'i', 'j', 'y', 'h'], 'fitness_score': 67}
# {'generation': 2, 'genes': ['v', 'j', 'o', 'l', 't', 's', 'r', 'a', 'n', 'x'], 'fitness_score': 67}
# {'generation': 1, 'genes': ['x', 'n', 'p', 'e', 'j', 'z', 'i', 'y', 'o', 'v'], 'fitness_score': 67}
# {'generation': 1, 'genes': ['n', 'j', 'g', 'r', 'q', 'o', 'm', 'p', 'i', 'w'], 'fitness_score': 68}
# {'generation': 2, 'genes': ['m', 'q', 'u', 'u', 'p', 'a', 'k', 'r', 'f', 'y'], 'fitness_score': 68}
# {'generation': 0, 'genes': ['r', 'g', 'u', 'v', 'x', 'y', 'n', 'l', 'a', 'm'], 'fitness_score': 69}
# {'generation': 1, 'genes': ['o', 'g', 't', 'w', 'y', 'p', 'v', 'r', 'b', 'd'], 'fitness_score': 69}
# {'generation': 1, 'genes': ['v', 'i', 'e', 'f', 'k', 's', 'd', 'a', 'k', 'c'], 'fitness_score': 69}
# {'generation': 2, 'genes': ['g', 'x', 'j', 'i', 'l', 'y', 'i', 'q', 'm', 'g'], 'fitness_score': 69}
# {'generation': 0, 'genes': ['j', 'r', 'x', 'd', 's', 'q', 'u', 'n', 'a', 'h'], 'fitness_score': 70}
# {'generation': 1, 'genes': ['s', 'q', 'c', 'v', 'f', 'x', 'b', 'g', 'n', 'b'], 'fitness_score': 70}
# {'generation': 0, 'genes': ['d', 'f', 't', 'h', 'g', 'z', 'c', 'y', 'r', 'v'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['j', 'x', 'b', 'i', 'k', 'e', 'p', 'o', 't', 'a'], 'fitness_score': 71}

# %%
test_world.iterate()
test_world.view_world()
# Out:
# Iteration: 4
# Successful Mating:  107
# Mating Tried, But Failed:  89
# {'generation': 0, 'genes': ['q', 'd', 'k', 'm', 'p', 'v', 'o', 'x', 'e', 'c'], 'fitness_score': 28}
# {'generation': 1, 'genes': ['t', 'h', 'm', 'b', 'c', 'b', 'p', 'e', 'g', 'd'], 'fitness_score': 43}
# {'generation': 0, 'genes': ['t', 'h', 'i', 'b', 'm', 'q', 'n', 'w', 'l', 'a'], 'fitness_score': 45}
# {'generation': 0, 'genes': ['f', 'e', 'n', 'k', 'a', 'q', 't', 'd', 'i', 'c'], 'fitness_score': 48}
# {'generation': 0, 'genes': ['m', 'b', 'f', 'j', 'n', 'p', 't', 'h', 'i', 'k'], 'fitness_score': 49}
# {'generation': 1, 'genes': ['j', 'h', 'h', 'p', 't', 'i', 'k', 't', 'i', 'p'], 'fitness_score': 49}
# {'generation': 0, 'genes': ['l', 'h', 'p', 'c', 'i', 't', 'o', 'q', 'v', 'n'], 'fitness_score': 50}
# {'generation': 2, 'genes': ['u', 'v', 'f', 'j', 'n', 'o', 'm', 'j', 'q', 'r'], 'fitness_score': 50}
# {'generation': 1, 'genes': ['g', 'b', 'a', 'o', 'r', 'h', 'z', 'w', 'l', 'n'], 'fitness_score': 51}
# {'generation': 0, 'genes': ['q', 'n', 'm', 's', 'r', 'u', 'l', 'x', 'v', 'a'], 'fitness_score': 53}
# {'generation': 0, 'genes': ['d', 'v', 'l', 'p', 'x', 'y', 'o', 't', 'r', 'm'], 'fitness_score': 53}
# {'generation': 0, 'genes': ['n', 'b', 'x', 'l', 'f', 's', 'p', 'w', 'a', 'g'], 'fitness_score': 54}
# {'generation': 2, 'genes': ['k', 'f', 'e', 'n', 'q', 'o', 'a', 'm', 'z', 'b'], 'fitness_score': 54}
# {'generation': 1, 'genes': ['i', 'u', 'g', 'k', 'z', 'l', 'm', 'i', 'e', 'w'], 'fitness_score': 55}
# {'generation': 2, 'genes': ['l', 'd', 'f', 'z', 'u', 'k', 'x', 'b', 'c', 'y'], 'fitness_score': 55}
# {'generation': 0, 'genes': ['t', 'l', 'i', 'k', 'q', 'z', 'j', 's', 'w', 'o'], 'fitness_score': 56}
# {'generation': 1, 'genes': ['g', 'u', 'v', 'l', 'x', 'n', 's', 'd', 'i', 'd'], 'fitness_score': 56}
# {'generation': 1, 'genes': ['f', 'k', 'd', 'o', 'i', 'l', 'z', 'k', 'r', 'j'], 'fitness_score': 57}
# {'generation': 1, 'genes': ['x', 'i', 'c', 'o', 'r', 's', 'n', 'k', 'u', 'a'], 'fitness_score': 57}
# {'generation': 1, 'genes': ['d', 'v', 'y', 'z', 's', 'c', 'z', 'w', 'b', 't'], 'fitness_score': 59}
# {'generation': 2, 'genes': ['n', 'u', 'a', 'i', 'p', 't', 'v', 'i', 'x', 'v'], 'fitness_score': 59}
# {'generation': 1, 'genes': ['k', 'v', 'a', 'w', 'h', 'e', 'b', 'k', 'g', 'o'], 'fitness_score': 59}
# {'generation': 0, 'genes': ['e', 'o', 'l', 'j', 's', 'p', 'f', 'w', 'v', 'n'], 'fitness_score': 60}
# {'generation': 1, 'genes': ['z', 'f', 'u', 'r', 'n', 'o', 's', 'j', 'v', 'c'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['g', 's', 'k', 'z', 'j', 't', 'e', 'v', 'f', 'h'], 'fitness_score': 62}
# {'generation': 1, 'genes': ['s', 'd', 'x', 'n', 'p', 'z', 'r', 'q', 'c', 'm'], 'fitness_score': 62}
# {'generation': 2, 'genes': ['q', 'f', 'i', 'n', 'z', 'y', 'l', 'r', 'u', 'j'], 'fitness_score': 62}
# {'generation': 2, 'genes': ['z', 'k', 'a', 'u', 'i', 't', 'o', 'h', 'n', 'm'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['k', 'x', 'n', 'r', 'u', 'w', 'q', 'y', 'i', 's'], 'fitness_score': 63}
# {'generation': 0, 'genes': ['r', 'a', 'p', 'v', 'o', 'i', 'c', 'm', 'j', 'g'], 'fitness_score': 64}
# {'generation': 1, 'genes': ['z', 'u', 's', 'i', 'j', 'v', 'c', 't', 'c', 'l'], 'fitness_score': 64}
# {'generation': 2, 'genes': ['e', 'd', 'q', 'z', 'x', 'k', 'r', 'f', 'f', 'u'], 'fitness_score': 64}
# {'generation': 2, 'genes': ['j', 'x', 'z', 'd', 't', 'b', 'h', 'r', 'o', 'm'], 'fitness_score': 64}
# {'generation': 3, 'genes': ['r', 'd', 'z', 'r', 'j', 'k', 'q', 'u', 'f', 'x'], 'fitness_score': 64}
# {'generation': 0, 'genes': ['c', 't', 'k', 'i', 'x', 'v', 'y', 'g', 'p', 'j'], 'fitness_score': 65}
# {'generation': 0, 'genes': ['s', 'r', 'j', 'i', 'l', 'z', 'n', 'o', 't', 'v'], 'fitness_score': 65}
# {'generation': 2, 'genes': ['q', 'i', 'o', 's', 'g', 'j', 'k', 'r', 'l', 'h'], 'fitness_score': 65}
# {'generation': 1, 'genes': ['f', 'w', 'a', 'z', 'j', 'b', 'g', 'q', 'd', 'r'], 'fitness_score': 66}
# {'generation': 1, 'genes': ['d', 'k', 'e', 'u', 'g', 'p', 'q', 'f', 'r', 'x'], 'fitness_score': 66}
# {'generation': 1, 'genes': ['x', 'k', 'q', 'h', 'i', 'w', 'p', 'a', 'c', 'q'], 'fitness_score': 66}
# {'generation': 1, 'genes': ['n', 'z', 'a', 'b', 'w', 'l', 'q', 'i', 'i', 'm'], 'fitness_score': 66}
# {'generation': 0, 'genes': ['c', 'n', 't', 'r', 'k', 'x', 'b', 'y', 'w', 'a'], 'fitness_score': 67}
# {'generation': 1, 'genes': ['g', 'v', 'x', 'q', 'y', 'd', 'i', 'j', 'y', 'h'], 'fitness_score': 67}
# {'generation': 2, 'genes': ['v', 'j', 'o', 'l', 't', 's', 'r', 'a', 'n', 'x'], 'fitness_score': 67}
# {'generation': 1, 'genes': ['x', 'n', 'p', 'e', 'j', 'z', 'i', 'y', 'o', 'v'], 'fitness_score': 67}
# {'generation': 1, 'genes': ['n', 'j', 'g', 'r', 'q', 'o', 'm', 'p', 'i', 'w'], 'fitness_score': 68}
# {'generation': 2, 'genes': ['m', 'q', 'u', 'u', 'p', 'a', 'k', 'r', 'f', 'y'], 'fitness_score': 68}
# {'generation': 0, 'genes': ['r', 'g', 'u', 'v', 'x', 'y', 'n', 'l', 'a', 'm'], 'fitness_score': 69}
# {'generation': 1, 'genes': ['o', 'g', 't', 'w', 'y', 'p', 'v', 'r', 'b', 'd'], 'fitness_score': 69}
# {'generation': 1, 'genes': ['v', 'i', 'e', 'f', 'k', 's', 'd', 'a', 'k', 'c'], 'fitness_score': 69}

# %% [markdown]
# ## Manual Analysis done, now automation

# %%
new_world = World()
new_world.view_world()
for i in range(100):
    new_world.iterate()
new_world.view_world()
# Out:
# Iteration: 0
# Successful Mating:  0
# Mating Tried, But Failed:  0
# {'generation': 0, 'genes': ['u', 'd', 'i', 'l', 'k', 'x', 'y', 't', 'c', 'j'], 'fitness_score': 49}
# {'generation': 0, 'genes': ['b', 'f', 'z', 'i', 'j', 's', 'w', 'r', 'u', 'd'], 'fitness_score': 50}
# {'generation': 0, 'genes': ['v', 'f', 'g', 'j', 'p', 'o', 'd', 'x', 'r', 'e'], 'fitness_score': 55}
# {'generation': 0, 'genes': ['s', 'f', 'q', 'p', 'g', 'v', 'w', 't', 'n', 'r'], 'fitness_score': 56}
# {'generation': 0, 'genes': ['h', 'n', 'f', 'i', 'r', 'z', 'u', 'j', 'm', 'v'], 'fitness_score': 57}
# {'generation': 0, 'genes': ['g', 'f', 'h', 's', 'd', 'q', 'n', 'e', 'w', 'b'], 'fitness_score': 57}
# {'generation': 0, 'genes': ['s', 'a', 'b', 'k', 'f', 't', 'j', 'u', 'h', 'n'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['q', 'i', 'a', 'g', 'j', 'p', 'w', 'm', 'f', 'e'], 'fitness_score': 61}
# {'generation': 0, 'genes': ['s', 'k', 'o', 'c', 'n', 'm', 'i', 't', 'h', 'p'], 'fitness_score': 64}
# {'generation': 0, 'genes': ['g', 'f', 'k', 'v', 's', 'w', 'n', 'e', 'x', 'z'], 'fitness_score': 65}
# {'generation': 0, 'genes': ['h', 't', 'p', 'n', 'u', 'k', 's', 'g', 'x', 'c'], 'fitness_score': 67}
# {'generation': 0, 'genes': ['g', 'p', 'm', 'c', 'z', 'r', 'o', 'v', 'b', 't'], 'fitness_score': 68}
# {'generation': 0, 'genes': ['t', 'i', 'h', 'p', 'o', 'j', 'q', 'b', 'v', 'a'], 'fitness_score': 68}
# {'generation': 0, 'genes': ['i', 'r', 't', 'f', 'v', 'y', 'g', 'l', 'm', 'u'], 'fitness_score': 69}
# {'generation': 0, 'genes': ['y', 'd', 'w', 'j', 'c', 'u', 'e', 'm', 's', 'h'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['w', 'u', 'j', 'd', 'x', 'q', 't', 'v', 'g', 'e'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['i', 'j', 'f', 'c', 'h', 'k', 'b', 'o', 'n', 'r'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['m', 'w', 'g', 'k', 'i', 's', 'r', 'f', 'x', 'j'], 'fitness_score': 72}
# {'generation': 0, 'genes': ['l', 'b', 's', 'y', 'h', 'v', 'r', 'i', 'c', 'u'], 'fitness_score': 73}
# {'generation': 0, 'genes': ['i', 'r', 'g', 'l', 'z', 'c', 'n', 'p', 'u', 'o'], 'fitness_score': 73}
# {'generation': 0, 'genes': ['w', 'd', 'b', 's', 'k', 'l', 'h', 'm', 'u', 'i'], 'fitness_score': 74}
# {'generation': 0, 'genes': ['t', 's', 'g', 'o', 'm', 'w', 'y', 'b', 'r', 'j'], 'fitness_score': 74}
# {'generation': 0, 'genes': ['d', 'b', 'x', 'i', 'z', 'k', 'h', 'r', 'f', 'u'], 'fitness_score': 75}
# {'generation': 0, 'genes': ['i', 't', 'v', 'o', 'j', 'r', 's', 'b', 'w', 'k'], 'fitness_score': 77}
# {'generation': 0, 'genes': ['b', 'q', 'm', 'a', 'w', 'f', 'l', 'h', 'v', 'c'], 'fitness_score': 79}
# {'generation': 0, 'genes': ['o', 'c', 'i', 'z', 'q', 'f', 'y', 'w', 'p', 't'], 'fitness_score': 80}
# {'generation': 0, 'genes': ['t', 's', 'o', 'f', 'a', 'm', 'h', 'p', 'q', 'l'], 'fitness_score': 81}
# {'generation': 0, 'genes': ['x', 'y', 'l', 'g', 'a', 'z', 'f', 'o', 's', 'i'], 'fitness_score': 82}
# {'generation': 0, 'genes': ['q', 'e', 'p', 'w', 'n', 'i', 'f', 'd', 'l', 'z'], 'fitness_score': 84}
# {'generation': 0, 'genes': ['p', 'j', 'z', 'e', 'm', 'l', 'y', 'n', 'h', 'w'], 'fitness_score': 84}
# {'generation': 0, 'genes': ['b', 'o', 'i', 'v', 'r', 'a', 'm', 'e', 'z', 'c'], 'fitness_score': 84}
# {'generation': 0, 'genes': ['z', 'r', 'f', 'd', 'n', 'l', 'g', 'y', 'q', 'k'], 'fitness_score': 84}
# {'generation': 0, 'genes': ['b', 'c', 'j', 'z', 'r', 'g', 'd', 'f', 'v', 'm'], 'fitness_score': 85}
# {'generation': 0, 'genes': ['q', 'w', 's', 'x', 'e', 'h', 'i', 'z', 'k', 'd'], 'fitness_score': 86}
# {'generation': 0, 'genes': ['j', 'c', 'u', 'q', 'a', 'd', 'b', 'w', 'y', 'i'], 'fitness_score': 87}
# {'generation': 0, 'genes': ['p', 'k', 'g', 'i', 'e', 'f', 'a', 'u', 'h', 'v'], 'fitness_score': 88}
# {'generation': 0, 'genes': ['z', 'e', 'f', 'u', 'h', 'q', 'b', 't', 'a', 'v'], 'fitness_score': 90}
# {'generation': 0, 'genes': ['b', 'o', 'i', 'w', 'x', 'e', 'h', 'u', 'v', 't'], 'fitness_score': 93}
# {'generation': 0, 'genes': ['x', 's', 'k', 'z', 'g', 'q', 'f', 'n', 'u', 'p'], 'fitness_score': 93}
# {'generation': 0, 'genes': ['r', 'v', 'h', 's', 'j', 'd', 'o', 'p', 'x', 'w'], 'fitness_score': 95}
# {'generation': 0, 'genes': ['v', 'q', 's', 'a', 't', 'g', 'u', 'i', 'z', 'c'], 'fitness_score': 95}
# {'generation': 0, 'genes': ['b', 't', 'p', 'z', 'l', 'j', 'f', 'a', 'h', 'n'], 'fitness_score': 95}
# {'generation': 0, 'genes': ['v', 'z', 'n', 'e', 'w', 'l', 'x', 'd', 't', 'g'], 'fitness_score': 97}
# {'generation': 0, 'genes': ['x', 'y', 'k', 'f', 't', 'l', 'i', 'e', 'd', 'r'], 'fitness_score': 100}
# {'generation': 0, 'genes': ['d', 'q', 'z', 'c', 'w', 'g', 'j', 'u', 'v', 'x'], 'fitness_score': 101}
# {'generation': 0, 'genes': ['t', 'p', 'r', 'c', 'v', 'n', 'f', 'j', 'u', 'z'], 'fitness_score': 102}
# {'generation': 0, 'genes': ['u', 'o', 'a', 't', 'w', 'g', 'd', 'f', 'c', 'j'], 'fitness_score': 104}
# {'generation': 0, 'genes': ['s', 'n', 'm', 'u', 'p', 'c', 'e', 'f', 'a', 'z'], 'fitness_score': 106}
# {'generation': 0, 'genes': ['u', 'm', 'x', 't', 'q', 'd', 'a', 'e', 'n', 'w'], 'fitness_score': 110}
# {'generation': 0, 'genes': ['w', 'u', 's', 'v', 'l', 'f', 'z', 'g', 'x', 't'], 'fitness_score': 118}
# Iteration: 100
# Successful Mating:  1531
# Mating Tried, But Failed:  3369
# {'generation': 3, 'genes': ['v', 'n', 'y', 'h', 'c', 'z', 'u', 'b', 'k', 'k'], 'fitness_score': 30}
# {'generation': 2, 'genes': ['o', 'g', 'q', 'u', 'd', 'n', 'l', 'y', 's', 'r'], 'fitness_score': 31}
# {'generation': 4, 'genes': ['r', 'r', 'd', 'a', 'u', 'u', 's', 'h', 'h', 'm'], 'fitness_score': 32}
# {'generation': 4, 'genes': ['u', 'z', 'j', 'h', 'm', 'q', 'e', 'r', 'w', 's'], 'fitness_score': 33}
# {'generation': 4, 'genes': ['r', 's', 'y', 'x', 'w', 'k', 'u', 'z', 'i', 'e'], 'fitness_score': 34}
# {'generation': 4, 'genes': ['c', 'r', 'w', 'n', 'u', 'm', 'k', 'c', 'z', 'j'], 'fitness_score': 35}
# {'generation': 4, 'genes': ['h', 'c', 'u', 't', 'b', 'i', 'm', 'l', 'f', 't'], 'fitness_score': 35}
# {'generation': 3, 'genes': ['e', 'f', 'i', 'w', 'm', 'k', 'h', 'd', 't', 'n'], 'fitness_score': 36}
# {'generation': 3, 'genes': ['p', 'z', 'q', 'r', 'b', 'h', 'n', 'w', 't', 'g'], 'fitness_score': 36}
# {'generation': 4, 'genes': ['y', 'v', 'a', 'b', 'z', 'k', 'w', 'x', 'q', 'o'], 'fitness_score': 37}
# {'generation': 3, 'genes': ['i', 's', 'x', 'y', 'o', 'a', 'd', 'f', 'p', 'w'], 'fitness_score': 39}
# {'generation': 2, 'genes': ['f', 'e', 'o', 'g', 't', 's', 's', 'i', 'k', 'p'], 'fitness_score': 42}
# {'generation': 2, 'genes': ['m', 's', 'h', 'w', 's', 't', 'f', 'h', 'n', 'i'], 'fitness_score': 42}
# {'generation': 3, 'genes': ['r', 'v', 'l', 'm', 't', 't', 'i', 'g', 'd', 'f'], 'fitness_score': 42}
# {'generation': 5, 'genes': ['c', 'w', 'e', 'g', 'l', 'a', 'e', 'b', 'h', 'h'], 'fitness_score': 42}
# {'generation': 4, 'genes': ['n', 'i', 'b', 'v', 'f', 'z', 't', 'r', 's', 'q'], 'fitness_score': 42}
# {'generation': 5, 'genes': ['f', 'r', 'p', 'w', 'm', 'y', 'a', 'z', 'h', 'q'], 'fitness_score': 42}
# {'generation': 2, 'genes': ['f', 'm', 'd', 'v', 'z', 'c', 't', 'j', 'v', 'o'], 'fitness_score': 43}
# {'generation': 2, 'genes': ['c', 'l', 'k', 'q', 'k', 'r', 'h', 'y', 'b', 'j'], 'fitness_score': 43}
# {'generation': 3, 'genes': ['j', 'h', 'k', 'j', 'm', 'a', 'z', 'd', 'x', 't'], 'fitness_score': 43}
# {'generation': 4, 'genes': ['q', 'y', 'r', 'e', 'e', 'j', 'i', 'g', 'x', 'o'], 'fitness_score': 43}
# {'generation': 1, 'genes': ['u', 'y', 'e', 'o', 'd', 'p', 'w', 'a', 'b', 'k'], 'fitness_score': 44}
# {'generation': 1, 'genes': ['s', 'u', 'j', 'f', 'n', 'z', 'v', 'k', 'c', 'n'], 'fitness_score': 44}
# {'generation': 3, 'genes': ['u', 'v', 'e', 'g', 'g', 'k', 'r', 's', 'e', 'z'], 'fitness_score': 44}
# {'generation': 3, 'genes': ['t', 'b', 'x', 'z', 'c', 'd', 'u', 'v', 'i', 'e'], 'fitness_score': 44}
# {'generation': 4, 'genes': ['v', 'w', 't', 'h', 'h', 'p', 'r', 'b', 'v', 'z'], 'fitness_score': 44}
# {'generation': 5, 'genes': ['f', 'u', 'x', 'b', 'w', 'd', 'u', 'v', 'm', 'h'], 'fitness_score': 44}
# {'generation': 4, 'genes': ['y', 'h', 'e', 'z', 'w', 'a', 'r', 'g', 'g', 'e'], 'fitness_score': 44}
# {'generation': 4, 'genes': ['h', 'b', 'w', 'h', 'm', 'k', 'v', 'r', 'f', 's'], 'fitness_score': 44}
# {'generation': 2, 'genes': ['c', 'l', 'w', 'q', 'z', 'b', 'f', 't', 'n', 'a'], 'fitness_score': 45}
# {'generation': 4, 'genes': ['g', 'e', 't', 'n', 's', 'd', 'a', 'j', 'x', 'm'], 'fitness_score': 45}
# {'generation': 5, 'genes': ['t', 'i', 'm', 'g', 'l', 'z', 'u', 'y', 'm', 'x'], 'fitness_score': 45}
# {'generation': 3, 'genes': ['v', 'a', 'w', 'c', 'h', 'j', 't', 'p', 'n', 'g'], 'fitness_score': 46}
# {'generation': 4, 'genes': ['k', 'f', 'x', 'r', 'j', 't', 'a', 'z', 'u', 'b'], 'fitness_score': 46}
# {'generation': 4, 'genes': ['n', 'r', 'q', 'h', 'a', 'a', 'i', 'z', 'v', 's'], 'fitness_score': 46}
# {'generation': 3, 'genes': ['g', 'k', 'v', 's', 'u', 'o', 'u', 'h', 'h', 'j'], 'fitness_score': 47}
# {'generation': 4, 'genes': ['o', 'z', 'v', 'x', 'u', 'k', 'u', 'g', 's', 'g'], 'fitness_score': 47}
# {'generation': 3, 'genes': ['m', 'v', 'd', 'a', 'j', 'l', 'b', 'c', 'f', 'w'], 'fitness_score': 47}
# {'generation': 4, 'genes': ['x', 't', 'j', 'v', 'z', 'm', 'y', 'i', 'd', 's'], 'fitness_score': 47}
# {'generation': 3, 'genes': ['e', 'z', 'p', 'c', 'i', 't', 'r', 'p', 'd', 'h'], 'fitness_score': 47}
# {'generation': 3, 'genes': ['d', 'l', 'a', 'p', 'v', 'b', 'r', 'o', 'y', 'm'], 'fitness_score': 47}
# {'generation': 3, 'genes': ['l', 'p', 'j', 'x', 'm', 'c', 'k', 'q', 'v', 'd'], 'fitness_score': 47}
# {'generation': 3, 'genes': ['c', 'u', 'z', 'g', 'q', 'w', 'a', 'x', 'p', 'e'], 'fitness_score': 48}
# {'generation': 4, 'genes': ['c', 'r', 'z', 'n', 'q', 'q', 'a', 'x', 'h', 'e'], 'fitness_score': 48}
# {'generation': 2, 'genes': ['n', 'r', 't', 'j', 'g', 'u', 'u', 's', 'h', 'e'], 'fitness_score': 48}
# {'generation': 4, 'genes': ['x', 'z', 'w', 'i', 'r', 's', 'a', 'o', 'v', 'j'], 'fitness_score': 48}
# {'generation': 5, 'genes': ['s', 'r', 'h', 'g', 'g', 'f', 'x', 'h', 'o', 'm'], 'fitness_score': 48}
# {'generation': 0, 'genes': ['u', 'd', 'i', 'l', 'k', 'x', 'y', 't', 'c', 'j'], 'fitness_score': 49}
# {'generation': 1, 'genes': ['n', 's', 'j', 'b', 'd', 'g', 'e', 'w', 'q', 'v'], 'fitness_score': 49}
# {'generation': 2, 'genes': ['y', 'a', 'z', 'b', 'n', 'p', 'n', 'g', 'z', 'e'], 'fitness_score': 49}

# %%
new_world = World()
new_world.view_world()
for i in range(1000000):
    new_world.iterate()
new_world.view_world()
# Out:
# Iteration: 0
# Successful Mating:  0
# Mating Tried, But Failed:  0
# {'generation': 0, 'genes': ['w', 'h', 'm', 'b', 't', 'z', 'n', 'o', 'l', 'g'], 'fitness_score': 44}
# {'generation': 0, 'genes': ['e', 'a', 'o', 'v', 'g', 'z', 's', 'u', 'q', 'j'], 'fitness_score': 49}
# {'generation': 0, 'genes': ['f', 'h', 'n', 'o', 'j', 'w', 'x', 'l', 'd', 'q'], 'fitness_score': 51}
# {'generation': 0, 'genes': ['g', 'd', 'i', 'q', 'z', 's', 'm', 'j', 'u', 'k'], 'fitness_score': 51}
# {'generation': 0, 'genes': ['m', 'b', 'j', 'x', 'v', 'r', 'y', 't', 'q', 'f'], 'fitness_score': 53}
# {'generation': 0, 'genes': ['d', 'f', 'w', 'q', 'o', 'r', 'g', 'n', 'e', 'l'], 'fitness_score': 53}
# {'generation': 0, 'genes': ['a', 'r', 'm', 'k', 'd', 'p', 's', 'o', 'h', 'f'], 'fitness_score': 53}
# {'generation': 0, 'genes': ['u', 'e', 'k', 'a', 'y', 'o', 'n', 'r', 'i', 'q'], 'fitness_score': 60}
# {'generation': 0, 'genes': ['p', 'f', 'r', 'k', 'd', 'u', 'c', 'g', 's', 'a'], 'fitness_score': 62}
# {'generation': 0, 'genes': ['i', 'n', 'r', 'j', 'g', 'h', 'u', 'y', 'k', 'l'], 'fitness_score': 63}
# {'generation': 0, 'genes': ['d', 'i', 'n', 'b', 'u', 's', 'l', 'm', 'r', 'z'], 'fitness_score': 66}
# {'generation': 0, 'genes': ['o', 'b', 'n', 'l', 'a', 'd', 'q', 'z', 'e', 'h'], 'fitness_score': 66}
# {'generation': 0, 'genes': ['n', 's', 'r', 'e', 'y', 'u', 'p', 'i', 'f', 'j'], 'fitness_score': 67}
# {'generation': 0, 'genes': ['h', 'e', 'w', 'x', 'i', 'f', 'n', 'a', 'o', 'd'], 'fitness_score': 67}
# {'generation': 0, 'genes': ['j', 'm', 'd', 'h', 'k', 'u', 's', 'l', 'v', 'w'], 'fitness_score': 67}
# {'generation': 0, 'genes': ['j', 'b', 'k', 'n', 'f', 'o', 'g', 'c', 'e', 'p'], 'fitness_score': 67}
# {'generation': 0, 'genes': ['n', 'l', 'i', 'j', 'f', 'w', 'u', 'a', 'b', 'k'], 'fitness_score': 67}
# {'generation': 0, 'genes': ['x', 'o', 'f', 'd', 'i', 'v', 'm', 'p', 'w', 'j'], 'fitness_score': 68}
# {'generation': 0, 'genes': ['c', 'h', 'u', 'j', 'p', 'r', 'e', 'g', 'd', 't'], 'fitness_score': 70}
# {'generation': 0, 'genes': ['b', 'g', 'r', 'a', 'x', 'n', 'z', 'k', 'v', 'd'], 'fitness_score': 71}
# {'generation': 0, 'genes': ['q', 'l', 'i', 'v', 'f', 'm', 'c', 'o', 't', 'a'], 'fitness_score': 74}
# {'generation': 0, 'genes': ['t', 'l', 'r', 'n', 'u', 'w', 'f', 'k', 'g', 'y'], 'fitness_score': 75}
# {'generation': 0, 'genes': ['t', 'k', 'x', 'q', 's', 'b', 'u', 'm', 'p', 'e'], 'fitness_score': 76}
# {'generation': 0, 'genes': ['o', 'j', 'r', 'x', 'v', 'i', 'l', 'g', 'w', 'e'], 'fitness_score': 77}
# {'generation': 0, 'genes': ['b', 't', 'p', 'd', 'n', 'f', 'y', 'x', 'j', 'l'], 'fitness_score': 77}
# {'generation': 0, 'genes': ['u', 'a', 'e', 'j', 'x', 'g', 'z', 'o', 'i', 'n'], 'fitness_score': 78}
# {'generation': 0, 'genes': ['x', 'j', 'y', 'q', 'h', 'm', 'u', 'n', 'b', 'g'], 'fitness_score': 79}
# {'generation': 0, 'genes': ['a', 'w', 'n', 't', 'y', 'h', 'l', 'm', 'u', 'g'], 'fitness_score': 80}
# {'generation': 0, 'genes': ['c', 's', 'g', 'w', 'o', 'm', 'x', 'n', 'l', 'z'], 'fitness_score': 80}
# {'generation': 0, 'genes': ['x', 'n', 'm', 'a', 'w', 'k', 'c', 't', 'f', 'g'], 'fitness_score': 80}
# {'generation': 0, 'genes': ['y', 'q', 'l', 'z', 'b', 'n', 'r', 'k', 'f', 'e'], 'fitness_score': 82}
# {'generation': 0, 'genes': ['p', 'f', 'w', 'o', 'j', 'n', 'u', 'd', 'x', 's'], 'fitness_score': 84}
# {'generation': 0, 'genes': ['m', 'n', 'e', 'p', 'w', 'j', 'z', 'h', 's', 'o'], 'fitness_score': 85}
# {'generation': 0, 'genes': ['k', 'x', 'r', 'u', 'j', 'p', 'b', 'm', 't', 'n'], 'fitness_score': 85}
# {'generation': 0, 'genes': ['q', 'g', 'i', 'a', 'd', 'o', 'e', 'f', 's', 'p'], 'fitness_score': 85}
# {'generation': 0, 'genes': ['b', 'v', 'k', 'n', 't', 'g', 'o', 'h', 'y', 'u'], 'fitness_score': 87}
# {'generation': 0, 'genes': ['r', 'n', 'w', 'e', 'z', 'q', 'p', 'x', 'c', 'u'], 'fitness_score': 87}
# {'generation': 0, 'genes': ['j', 'i', 's', 'z', 'x', 'l', 'f', 'c', 'b', 'k'], 'fitness_score': 88}
# {'generation': 0, 'genes': ['k', 's', 'a', 'x', 'z', 'g', 't', 'w', 'p', 'o'], 'fitness_score': 92}
# {'generation': 0, 'genes': ['t', 'z', 'r', 'q', 'd', 'b', 'f', 'u', 'k', 'g'], 'fitness_score': 92}
# {'generation': 0, 'genes': ['m', 's', 'e', 'b', 'h', 'd', 'c', 'q', 'n', 'u'], 'fitness_score': 94}
# {'generation': 0, 'genes': ['y', 'v', 'z', 'n', 'o', 'd', 'w', 'b', 'k', 'e'], 'fitness_score': 95}
# {'generation': 0, 'genes': ['u', 'x', 'n', 'k', 'v', 'f', 'e', 's', 'b', 't'], 'fitness_score': 96}
# {'generation': 0, 'genes': ['m', 'q', 'x', 't', 'e', 'p', 'f', 'd', 'g', 'v'], 'fitness_score': 100}
# {'generation': 0, 'genes': ['r', 't', 's', 'c', 'a', 'f', 'z', 'e', 'l', 'k'], 'fitness_score': 103}
# {'generation': 0, 'genes': ['p', 'j', 'y', 'z', 'w', 'g', 'x', 'c', 'm', 'r'], 'fitness_score': 103}
# {'generation': 0, 'genes': ['t', 's', 'o', 'u', 'c', 'h', 'e', 'f', 'a', 'q'], 'fitness_score': 111}
# {'generation': 0, 'genes': ['p', 'y', 'n', 'b', 'f', 'c', 'e', 'j', 'x', 'q'], 'fitness_score': 112}
# {'generation': 0, 'genes': ['x', 'z', 'i', 'e', 'b', 'f', 'q', 'c', 'm', 'v'], 'fitness_score': 113}
# {'generation': 0, 'genes': ['m', 'p', 'a', 'y', 'n', 'c', 'x', 'f', 'u', 'z'], 'fitness_score': 113}
# Iteration: 1000000
# Successful Mating:  12387803
# Mating Tried, But Failed:  36612197
# {'generation': 14, 'genes': ['e', 'g', 'j', 'h', 't', 't', 'k', 's', 'r', 'a'], 'fitness_score': 11}
# {'generation': 13, 'genes': ['v', 'l', 'u', 'y', 'v', 'v', 'm', 's', 'i', 'v'], 'fitness_score': 11}
# {'generation': 10, 'genes': ['n', 'v', 'd', 'p', 'y', 'z', 'u', 'v', 'r', 'x'], 'fitness_score': 12}
# {'generation': 11, 'genes': ['p', 'v', 'u', 'p', 'm', 'r', 'b', 'h', 'd', 'z'], 'fitness_score': 12}
# {'generation': 15, 'genes': ['r', 'h', 's', 'x', 'j', 'g', 'i', 'b', 'v', 'd'], 'fitness_score': 12}
# {'generation': 10, 'genes': ['p', 't', 'a', 'a', 'b', 'u', 'o', 'v', 'b', 't'], 'fitness_score': 13}
# {'generation': 12, 'genes': ['i', 'o', 'l', 'j', 'u', 'n', 'e', 'v', 'c', 'm'], 'fitness_score': 13}
# {'generation': 14, 'genes': ['r', 'c', 'x', 'r', 'o', 'l', 'n', 'j', 's', 'z'], 'fitness_score': 13}
# {'generation': 11, 'genes': ['j', 'r', 'p', 'k', 'n', 'b', 'v', 'u', 't', 'y'], 'fitness_score': 14}
# {'generation': 13, 'genes': ['p', 'u', 'j', 'a', 's', 'c', 'v', 'y', 'd', 'v'], 'fitness_score': 14}
# {'generation': 13, 'genes': ['p', 's', 'y', 'd', 'd', 'm', 'o', 'w', 'e', 'm'], 'fitness_score': 14}
# {'generation': 13, 'genes': ['r', 'k', 'o', 'x', 'e', 'g', 'p', 'b', 'a', 'o'], 'fitness_score': 14}
# {'generation': 10, 'genes': ['n', 'o', 't', 'x', 'r', 'v', 'i', 'd', 'c', 'z'], 'fitness_score': 15}
# {'generation': 12, 'genes': ['g', 'i', 'y', 'u', 'm', 'j', 'c', 'o', 'd', 'e'], 'fitness_score': 15}
# {'generation': 11, 'genes': ['n', 'g', 'y', 'q', 'o', 'v', 'v', 'p', 'x', 'l'], 'fitness_score': 15}
# {'generation': 12, 'genes': ['y', 'o', 'j', 'h', 'c', 'q', 'j', 'd', 'l', 'w'], 'fitness_score': 15}
# {'generation': 12, 'genes': ['w', 'm', 'v', 'v', 't', 'r', 'j', 'u', 'v', 'i'], 'fitness_score': 15}
# {'generation': 14, 'genes': ['l', 'i', 'u', 'y', 'd', 'w', 'y', 'z', 'k', 'r'], 'fitness_score': 15}
# {'generation': 12, 'genes': ['m', 'f', 'v', 'y', 's', 'a', 'l', 'v', 'n', 'x'], 'fitness_score': 15}
# {'generation': 13, 'genes': ['l', 'v', 'd', 'n', 'a', 'm', 'f', 'v', 's', 'v'], 'fitness_score': 15}
# {'generation': 7, 'genes': ['a', 'v', 'g', 'd', 'k', 's', 'o', 'r', 'z', 'u'], 'fitness_score': 16}
# {'generation': 6, 'genes': ['b', 'u', 'm', 'h', 'v', 'x', 'k', 'y', 'c', 'n'], 'fitness_score': 16}
# {'generation': 10, 'genes': ['a', 'a', 'r', 'c', 'y', 'z', 'd', 'c', 'z', 'r'], 'fitness_score': 16}
# {'generation': 11, 'genes': ['l', 'c', 'p', 'l', 'k', 'v', 't', 'h', 'u', 'j'], 'fitness_score': 16}
# {'generation': 12, 'genes': ['q', 'x', 'n', 'f', 's', 'h', 'w', 'y', 'k', 'u'], 'fitness_score': 16}
# {'generation': 10, 'genes': ['v', 'k', 'x', 'i', 'h', 't', 'a', 's', 'w', 'c'], 'fitness_score': 16}
# {'generation': 11, 'genes': ['o', 'w', 'h', 'z', 'x', 'u', 'r', 'p', 'p', 'n'], 'fitness_score': 16}
# {'generation': 12, 'genes': ['y', 'b', 'm', 'o', 'e', 'a', 'd', 'z', 'v', 'k'], 'fitness_score': 16}
# {'generation': 12, 'genes': ['z', 'g', 'm', 'o', 'p', 'n', 'd', 't', 's', 'r'], 'fitness_score': 16}
# {'generation': 13, 'genes': ['j', 'q', 'j', 'u', 'f', 'v', 'h', 'a', 'b', 'i'], 'fitness_score': 16}
# {'generation': 13, 'genes': ['v', 'y', 'm', 'a', 's', 'j', 'd', 'k', 'p', 'l'], 'fitness_score': 16}
# {'generation': 12, 'genes': ['q', 'o', 'v', 'e', 'r', 'a', 'g', 'j', 'v', 's'], 'fitness_score': 16}
# {'generation': 13, 'genes': ['e', 'k', 'g', 'v', 'c', 'p', 'z', 'w', 'j', 'v'], 'fitness_score': 16}
# {'generation': 13, 'genes': ['r', 'j', 'j', 'w', 'l', 'b', 'v', 'o', 'm', 'j'], 'fitness_score': 16}
# {'generation': 14, 'genes': ['d', 'z', 'x', 'r', 'w', 'v', 'e', 'v', 'n', 'f'], 'fitness_score': 16}
# {'generation': 13, 'genes': ['v', 'u', 'n', 'l', 'h', 'y', 'q', 'v', 'j', 'm'], 'fitness_score': 16}
# {'generation': 13, 'genes': ['y', 'l', 'v', 'a', 'c', 'e', 'm', 's', 'w', 'o'], 'fitness_score': 16}
# {'generation': 14, 'genes': ['l', 'j', 'h', 'u', 'd', 'y', 's', 'o', 'c', 'y'], 'fitness_score': 16}
# {'generation': 14, 'genes': ['b', 'h', 'd', 'j', 'u', 'v', 'w', 's', 'n', 'e'], 'fitness_score': 16}
# {'generation': 14, 'genes': ['r', 'a', 'w', 's', 'q', 'w', 'j', 'm', 'h', 'd'], 'fitness_score': 16}
# {'generation': 15, 'genes': ['q', 'j', 'd', 'o', 'w', 'x', 'h', 's', 'f', 'u'], 'fitness_score': 16}
# {'generation': 7, 'genes': ['u', 'd', 't', 'y', 'y', 'w', 'i', 'r', 'm', 'x'], 'fitness_score': 17}
# {'generation': 12, 'genes': ['d', 'o', 'j', 'a', 'y', 't', 'v', 'b', 'h', 's'], 'fitness_score': 17}
# {'generation': 12, 'genes': ['m', 'v', 'd', 'v', 'y', 'j', 'v', 'r', 'v', 'q'], 'fitness_score': 17}
# {'generation': 10, 'genes': ['x', 's', 't', 'r', 'n', 't', 'u', 'v', 'w', 'd'], 'fitness_score': 17}
# {'generation': 13, 'genes': ['j', 'y', 'i', 'r', 'o', 'e', 'b', 'v', 'd', 'u'], 'fitness_score': 17}
# {'generation': 13, 'genes': ['e', 't', 't', 'r', 't', 'a', 'g', 'h', 'v', 'd'], 'fitness_score': 17}
# {'generation': 14, 'genes': ['k', 'c', 'y', 'a', 'e', 'g', 'j', 'v', 'y', 'y'], 'fitness_score': 17}
# {'generation': 14, 'genes': ['i', 'y', 'v', 'c', 'm', 'q', 'l', 'k', 's', 't'], 'fitness_score': 17}
# {'generation': 15, 'genes': ['l', 'y', 's', 'o', 'p', 'v', 'r', 'k', 'f', 'c'], 'fitness_score': 17}

# %% [markdown]
# # Automated Test confirms there is some issues with the shuffling system and the logic of my world. Organisms must die after 3-5 geerations. maybe will make this dying random. This is sad. Even in a computer generated world, death is inevident, death is neccessity
